# %% [markdown]
# Importamos librerías y definimos rutas

# %%
from PIL import Image, ImageDraw
import geopandas as gpd
import arcpy
import os
import time
import json
import keyboard
import shapely.geometry
import glob
import shutil
import random

# Ruta del proyecto de ArcGIS Pro
project_path = r"C:\Users\hugoh\OneDrive\Documentos\ArcGIS\Projects\TFG_palmeras\TFG_palmeras.aprx"

# Ruta del archivo Shapefile con las palmeras
shapefile_path = r"F:\Universidad\Curso 2024-25\Segundo Semestre\TFG\Desarrollo\Mapa_IDECanarias_Palmeras/99_K_Mapapalmerascanarias.shp"

# Carpeta de salida para las imágenes
output_folder = r"F:\Universidad\Curso 2024-25\Segundo Semestre\TFG\Desarrollo\dataset\fixed_normalization_ambiente"

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %% [markdown]
# Comprobamos las coordenadas del shapefile y de la vista activa de cámara

# %%
# Cargar las coordenadas de las palmeras
data = gpd.read_file(shapefile_path)

# Abrir el proyecto de ArcGIS Pro
project = arcpy.mp.ArcGISProject("current")
map_view = project.activeView

if map_view == None:
    raise ValueError("No se encontró ninguna vista activa en ArcGIS Pro. Abre el mapa manualmente y vuelve a ejecutar el script.")

# %% [markdown]
# Chequeamos el sistemas de las coordenadas y convertimos al mismo de la vista activa para unificar valores

# %%
# --- Asegurar que el mapa está en UTM Zona 28N ---
sr_utm = arcpy.SpatialReference(32628)
camera = map_view.camera
camera.spatialReference = sr_utm
map_view.camera = camera
print("Sistema de coordenadas fijado a UTM Zona 28N (EPSG:32628)")
print("Sistema de coordenadas después del cambio", map_view.camera.getExtent().spatialReference)
# --- Convertir las palmeras a UTM si fuera necesario ---
data_gc = data[data["ISLA"] == "GRAN CANARIA"]  # Filtrar solo Gran Canaria
print(data_gc.head())
print("Revisando sistema de coordenadas de las palmeras...")
if data_gc.crs.to_epsg() != 32628:
    print("Convirtiendo palmeras a UTM Zona 28N (EPSG:32628)...")
    data_gc = data_gc.to_crs(epsg=32628)
print("Sistema de coordenadas de las palmeras confirmado: UTM Zona 28N (EPSG:32628)")
# Out:
# Sistema de coordenadas fijado a UTM Zona 28N (EPSG:32628)
# Sistema de coordenadas después del cambio <geoprocessing spatial reference object object at 0x000002A727C7F570>
#                  Id_palm Tip_amb                       Tip_amb_de Hibrid  \
# 132957  Cx454646y3100878       ?  Ambientes de difícil asignación   None
# 132958  Cx454653y3100874       ?  Ambientes de difícil asignación   None
# 132959  Cx454659y3100870       ?  Ambientes de difícil asignación   None
# 132960  Cx454677y3100862       ?  Ambientes de difícil asignación   None
# 132961  Cx454672y3100865       ?  Ambientes de difícil asignación   None
#
#                 Hibrid_de          ISLA      MUNICIPIO  \
# 132957  Palmeras canarias  GRAN CANARIA  SANTA BRÍGIDA
# 132958  Palmeras canarias  GRAN CANARIA  SANTA BRÍGIDA
# 132959  Palmeras canarias  GRAN CANARIA  SANTA BRÍGIDA
# 132960  Palmeras canarias  GRAN CANARIA  SANTA BRÍGIDA
# 132961  Palmeras canarias  GRAN CANARIA  SANTA BRÍGIDA
#
#                               geometry
# 132957  POINT (454646.195 3100878.293)
# 132958  POINT (454653.074 3100873.663)
# 132959  POINT (454659.424 3100870.488)
# 132960  POINT (454677.416 3100862.022)
# 132961  POINT (454672.124 3100865.329)
# Revisando sistema de coordenadas de las palmeras...
# Sistema de coordenadas de las palmeras confirmado: UTM Zona 28N (EPSG:32628)

# %% [markdown]
# Funciones que convierten las coordenadas en objetos PointGeometry para comparar si se encuentran dentro de una extensión con poligon geometry.

# %%
# Función para comprobar si una coordenada está dentro del extent exportado
def is_in_exported_image(x_real, y_real, extent,  img_width, img_height):
    """"
    x_real, y_real: coordenadas en el mapa de la palmera
    extent: extent del mapa exportado
    :return: (bool, x_pixel, y_pixel) donde x_pixel y y_pixel son las coordenadas de la palmera u objeto en píxeles
    """
    x_pixel = ((x_real - extent.XMin) / extent.width) * img_width
    y_pixel = ((extent.YMax - y_real) / extent.height) * img_height

    inside = (0 <= x_pixel <= img_width) and (0 <= y_pixel <= img_height)
    return inside, x_pixel, y_pixel

# %%
# Verificar si existen palmeras con valor en el campo "Hibrid"
palmeras_con_hibrid = data_gc[~data_gc["Hibrid"].isna()]

if not palmeras_con_hibrid.empty:
    print(f"✅ Se encontraron {len(palmeras_con_hibrid)} palmeras con 'Hibrid' distinto de null.")
    print(palmeras_con_hibrid[["Hibrid", "Hibrid_de"]].head())
else:
    print("❌ No se encontraron palmeras con 'Hibrid' distinto de null.")
# Out:
# ✅ Se encontraron 5393 palmeras con 'Hibrid' distinto de null.
#        Hibrid                         Hibrid_de
# 134174    bdc  Híbridos - Baja densidad de copa
# 134175    hme        Híbridos - Hoja más erecta
# 134176    hme        Híbridos - Hoja más erecta
# 134177    hme        Híbridos - Hoja más erecta
# 134178    hme        Híbridos - Hoja más erecta

# %%
print("Longitud dataset gc", len(data_gc))
# Out:
# Longitud dataset gc 176430

# %%
folders = {
    "train": os.path.join(output_folder, "Train"),
    "val": os.path.join(output_folder, "Val"),
    "test": os.path.join(output_folder, "Test")
}

for folder in folders.values():
    os.makedirs(os.path.join(folder, "images"), exist_ok=True)
    os.makedirs(os.path.join(folder, "labels_ambiente"), exist_ok=True)
    os.makedirs(os.path.join(folder, "labels_palmera"), exist_ok=True)
    os.makedirs(os.path.join(folder, "labels_binaria"), exist_ok=True)
    os.makedirs(os.path.join(folder, "json_annotations"), exist_ok=True)
    os.makedirs(os.path.join(folder, "with_bbox"), exist_ok=True)
    os.makedirs(os.path.join(folder, "worldfiles"), exist_ok=True)
    os.makedirs(os.path.join(folder, "label_number_class"), exist_ok=True)

# --- Inicialización de ArcGIS ---
project = arcpy.mp.ArcGISProject("CURRENT")
map_view = project.activeView
camera = map_view.camera
sr_utm = arcpy.SpatialReference(32628)
camera.spatialReference = sr_utm
map_view.camera = camera

# --- Cargar y convertir el shapefile ---
data = data.to_crs(epsg=32628) if data.crs.to_epsg() != 32628 else data
islas = {"train": "GRAN CANARIA", "val": "TENERIFE", "test": "LA GOMERA"}
data_split = {k: data[data["ISLA"] == v].copy() for k, v in islas.items()}

# --- Crear diccionarios de clases ---
data_gc = data_split["train"]
data_gc["Hibrid"] = data_gc["Hibrid"].fillna("pc")
ambiente_classes = {k: i for i, k in enumerate(sorted(data_gc["Tip_amb"].dropna().unique()))}
palmera_classes = {k: i for i, k in enumerate(sorted(data_gc["Hibrid"].unique()))}

# --- Guardar las clases ---
for subset, folder in folders.items():
    with open(os.path.join(folder, "labels_ambiente", "labels.txt"), "w", encoding="utf-8") as f:
        for name in ambiente_classes:
            f.write(f"{name}\n")
    with open(os.path.join(folder, "labels_palmera", "labels.txt"), "w", encoding="utf-8") as f:
        for name in palmera_classes:
            f.write(f"{name}\n")
    with open(os.path.join(folder, "labels_binaria", "labels.txt"), "w", encoding="utf-8") as f:
        f.write("palmera\n")
    with open(os.path.join(folder, "label_number_class", "ambiente_classes.txt"), "w", encoding="utf-8") as f:
        for name, idx in ambiente_classes.items():
            f.write(f"{idx}: {name}\n")
    with open(os.path.join(folder, "label_number_class", "palmera_classes.txt"), "w", encoding="utf-8") as f:
        for name, idx in palmera_classes.items():
            f.write(f"{idx}: {name}\n")

# --- Parámetros comunes ---
resolution_m_per_px = 0.25
box_size = 60
map_scale = 500

# --- Funciones auxiliares ---
def export_annotation(image_name, palms, extent, width, height, folder):
    json_path = os.path.join(folder, "json_annotations", image_name.replace(".png", ".json"))
    with open(json_path, "w", encoding="utf-8") as jf:
        json.dump({"image": image_name, "extent": extent.JSON, "palms": palms}, jf, indent=4)

    label_path_amb = os.path.join(folder, "labels_ambiente", image_name.replace(".png", ".txt"))
    label_path_hyb = os.path.join(folder, "labels_palmera", image_name.replace(".png", ".txt"))
    label_path_bin = os.path.join(folder, "labels_binaria", image_name.replace(".png", ".txt"))

    # Mover worldfile
    pgw_path = image_name.replace(".png", ".pgw")
    pgw_src = os.path.join(folder, "images", pgw_path)
    pgw_dst = os.path.join(folder, "worldfiles", pgw_path)
    if os.path.exists(pgw_src):
        os.replace(pgw_src, pgw_dst)

    with open(label_path_amb, "w", encoding="utf-8") as f_amb, \
         open(label_path_hyb, "w", encoding="utf-8") as f_hyb, \
         open(label_path_bin, "w", encoding="utf-8") as f_bin:
        with open(pgw_dst) as wf:
            A, D, B, E, C, F = [float(wf.readline()) for _ in range(6)]

        for palm in palms:
            x_geo, y_geo = palm["real_coordinates"]["x"], palm["real_coordinates"]["y"]
            w, h = palm["bbox_pixel"]["width"], palm["bbox_pixel"]["height"]
            x_px = int((x_geo - C) / A)
            y_px = int((y_geo - F) / E)
            x_norm = float(x_px) / width
            y_norm = float(y_px) / height
            w_norm = float(w) / width
            h_norm = float(h) / height

            amb = ambiente_classes.get(palm["attributes"].get("Tip_amb"), -1)
            hyb = palmera_classes.get(palm["attributes"].get("Hibrid", "pc"), -1)

            if amb != -1:
                f_amb.write(f"{amb} {x_norm:.6f} {y_norm:.6f} {w_norm:.6f} {h_norm:.6f}\n")
            if hyb != -1:
                f_hyb.write(f"{hyb} {x_norm:.6f} {y_norm:.6f} {w_norm:.6f} {h_norm:.6f}\n")
            f_bin.write(f"0 {x_norm:.6f} {y_norm:.6f} {w_norm:.6f} {h_norm:.6f}\n")

    # Dibujar bbox
    img_path = os.path.join(folder, "images", image_name)
    if os.path.exists(img_path) and os.path.exists(pgw_dst):
        img = Image.open(img_path).copy()
        draw = ImageDraw.Draw(img)
        with open(pgw_dst) as wf:
            A, D, B, E, C, F = [float(wf.readline()) for _ in range(6)]
        for palm in palms:
            x_geo, y_geo = palm["real_coordinates"]["x"], palm["real_coordinates"]["y"]
            w = palm["bbox_pixel"]["width"]
            h = palm["bbox_pixel"]["height"]
            x_px = int((x_geo - C) / A)
            y_px = int((y_geo - F) / E)
            draw.rectangle([(x_px - w//2, y_px - h//2), (x_px + w//2, y_px + h//2)], outline="red", width=2)
        img.save(os.path.join(folder, "with_bbox", image_name))

# --- Función para procesamiento por conjunto ---
def process_island(data_island, folder, max_palms):
    processed = set()
    index = 0
    counter = 0
    while (index < len(data_island) and counter < max_palms):
        if keyboard.is_pressed('esc'):
            print("⛔ Ejecución interrumpida manualmente con ESC.")
            break
        
        for offset in range(40):
        #for offset in range(100):
            if index + offset >= len(data_island):
                break
            row = data_island.iloc[index]
            idx = row.name
            if idx in processed:
                #index += 1
                continue

            camera.X, camera.Y = row.geometry.x, row.geometry.y
            camera.scale = map_scale
            map_view.camera = camera
            time.sleep(1)

            extent = map_view.camera.getExtent()
            w_m = extent.XMax - extent.XMin
            h_m = extent.YMax - extent.YMin
            width_px = int(w_m / resolution_m_per_px)
            height_px = int(h_m / resolution_m_per_px)

            image_name = f"palmera_{idx}.png"
            image_path = os.path.join(folder, "images", image_name)
            map_view.exportToPNG(image_path, width_px, height_px, world_file=True)

            box = shapely.geometry.box(extent.XMin, extent.YMin, extent.XMax, extent.YMax)
            palms = []
            for j, palm_row in data_island[data_island.geometry.within(box)].iterrows():
                if j in processed:
                    continue
                x, y = palm_row.geometry.x, palm_row.geometry.y
                x_px = ((x - extent.XMin) / w_m) * width_px
                y_px = ((extent.YMax - y) / h_m) * height_px
                palms.append({
                    "tree_id": j,
                    "real_coordinates": {"x": x, "y": y},
                    "attributes": palm_row.drop("geometry").to_dict(),
                    "bbox_pixel": {""
                        "x_center": int(x_px), 
                        "y_center": int(y_px), 
                        "width": box_size, 
                        "height": box_size
                    },
                    "image_size_px": (width_px, height_px)
                })
                processed.add(j)

        if palms:
            export_annotation(image_name, palms, extent, width_px, height_px, folder)
            counter += len(palms)
        index += 400
    return counter

# --- Ejecutar procesamiento en orden Train/Val/Test ---
total_gc = process_island(data_split["train"], folders["train"], float("inf"))
# Si las palmeras de gc representan el 70% del total, el total será ese numero más un 30% del mismo
total_palms_dataset = total_gc + (total_gc * 0.3)
val_count = int(total_palms_dataset * 0.2)
test_count = int(total_palms_dataset * 0.1)
total_tnf = process_island(data_split["val"], folders["val"], val_count)
total_gomera = process_island(data_split["test"], folders["test"], test_count)

print("✅ Dataset completo generado con la estructura Train/Val/Test.")
print(f"Numero de palmeras de GC: {total_gc}")
print(f"Numero de palmeras de TNF: {total_tnf}")
print(f"Numero de palmeras de LA GOMERA: {total_gomera}")
print(f"Numero de palmeras totales: {total_palms_dataset} y suma que debe ser lo mismo {total_gc + total_tnf + total_gomera}")

# --- Mostrar recuento de imágenes y anotaciones YOLO por conjunto ---
def count_annotations(folder_name):
    image_dir = os.path.join(folder_name, "images")
    label_dir = os.path.join(folder_name, "labels_binaria")
    num_images = len([f for f in os.listdir(image_dir) if f.endswith(".png")])
    num_labels = len([f for f in os.listdir(label_dir) if f.endswith(".txt")])
    return num_images, num_labels

print("\n📊 Resumen del dataset generado:")
for split in ["train", "val", "test"]:
    img_count, label_count = count_annotations(folders[split])
    print(f"📂 {split.capitalize()}: {img_count} imágenes | {label_count} anotaciones")
# Out:
# ✅ Dataset completo generado con la estructura Train/Val/Test.
# Numero de palmeras de GC: 15806
# Numero de palmeras de TNF: 4111
# Numero de palmeras de LA GOMERA: 2067
# Numero de palmeras totales: 20547.8 y suma que debe ser lo mismo 21984
#
# 📊 Resumen del dataset generado:
# 📂 Train: 440 imágenes | 441 anotaciones
# 📂 Val: 85 imágenes | 86 anotaciones
# 📂 Test: 56 imágenes | 57 anotaciones

# %%
from PIL import Image, ImageDraw

folders = {
    "train": os.path.join(output_folder, "Train"),
    "val": os.path.join(output_folder, "Val"),
    "test": os.path.join(output_folder, "Test")
}

# --- Cargar y convertir el shapefile ---
data = data.to_crs(epsg=32628) if data.crs.to_epsg() != 32628 else data
islas = {"train": "GRAN CANARIA", "val": "TENERIFE", "test": "LA GOMERA"}
data_split = {k: data[data["ISLA"] == v].copy() for k, v in islas.items()}

# --- Crear diccionarios de clases ---
data_gc = data_split["train"]
data_gc["Hibrid"] = data_gc["Hibrid"].fillna("pc")
ambiente_classes = {k: i for i, k in enumerate(sorted(data_gc["Tip_amb"].dropna().unique()))}
palmera_classes = {k: i for i, k in enumerate(sorted(data_gc["Hibrid"].unique()))}

def modificar_todos_los_labels(folders, nuevo_box_size, ambiente_classes, palmera_classes):
    for split, folder in folders.items():
        print(f"🛠 Procesando conjunto: {split.upper()}")
        json_dir = os.path.join(folder, "json_annotations")
        image_dir = os.path.join(folder, "images")

        for json_file in os.listdir(json_dir):
            if not json_file.endswith(".json"):
                continue

            json_path = os.path.join(json_dir, json_file)
            image_name = json_file.replace(".json", ".png")
            image_path = os.path.join(image_dir, image_name)

            if not os.path.exists(image_path):
                print(f"⚠ Imagen no encontrada para {json_file}")
                continue

            with open(json_path, "r", encoding="utf-8") as f:
                data_json = json.load(f)

            palms = data_json["palms"]
            extent_data = json.loads(data_json["extent"])  # Convertir string a dict
            extent = arcpy.Extent(
                extent_data["xmin"],
                extent_data["ymin"],
                extent_data["xmax"],
                extent_data["ymax"]
            )
            image = Image.open(image_path)
            width, height = image.size

            for palm in palms:
                palm["bbox_pixel"]["width"] = nuevo_box_size
                palm["bbox_pixel"]["height"] = nuevo_box_size

            export_annotation(
                image_name=image_name,
                palms=palms,
                extent=extent,
                width=width,
                height=height,
                folder=folder,
                ambiente_classes=ambiente_classes,
                palmera_classes=palmera_classes
            )

        print(f"✅ Anotaciones actualizadas en {split.upper()}.\n")

def export_annotation(image_name, palms, extent, width, height, folder, ambiente_classes, palmera_classes):
    import shapely.geometry
    from PIL import ImageDraw

    json_path = os.path.join(folder, "json_annotations", image_name.replace(".png", ".json"))
    with open(json_path, "w", encoding="utf-8") as jf:
        json.dump({"image": image_name, "extent": extent.JSON, "palms": palms}, jf, indent=4)

    label_path_amb = os.path.join(folder, "labels_ambiente", image_name.replace(".png", ".txt"))
    label_path_hyb = os.path.join(folder, "labels_palmera", image_name.replace(".png", ".txt"))
    label_path_bin = os.path.join(folder, "labels_binaria", image_name.replace(".png", ".txt"))

    # Mover worldfile
    pgw_path = image_name.replace(".png", ".pgw")
    pgw_src = os.path.join(folder, "images", pgw_path)
    pgw_dst = os.path.join(folder, "worldfiles", pgw_path)
    if os.path.exists(pgw_src):
        os.replace(pgw_src, pgw_dst)

    with open(label_path_amb, "w", encoding="utf-8") as f_amb, \
         open(label_path_hyb, "w", encoding="utf-8") as f_hyb, \
         open(label_path_bin, "w", encoding="utf-8") as f_bin:
        with open(pgw_dst) as wf:
            A, D, B, E, C, F = [float(wf.readline()) for _ in range(6)]

        for palm in palms:
            x_geo, y_geo = palm["real_coordinates"]["x"], palm["real_coordinates"]["y"]
            w, h = palm["bbox_pixel"]["width"], palm["bbox_pixel"]["height"]
            x_px = int((x_geo - C) / A)
            y_px = int((y_geo - F) / E)
            x_norm = float(x_px) / width
            y_norm = float(y_px) / height
            w_norm = float(w) / width
            h_norm = float(h) / height

            amb = ambiente_classes.get(palm["attributes"].get("Tip_amb"), -1)
            hyb = palmera_classes.get(palm["attributes"].get("Hibrid", "pc"), -1)

            if amb != -1:
                f_amb.write(f"{amb} {x_norm:.6f} {y_norm:.6f} {w_norm:.6f} {h_norm:.6f}\n")
            if hyb != -1:
                f_hyb.write(f"{hyb} {x_norm:.6f} {y_norm:.6f} {w_norm:.6f} {h_norm:.6f}\n")
            f_bin.write(f"0 {x_norm:.6f} {y_norm:.6f} {w_norm:.6f} {h_norm:.6f}\n")

    # Dibujar bbox
    img_path = os.path.join(folder, "images", image_name)
    img = Image.open(img_path).copy()
    draw = ImageDraw.Draw(img)
    with open(pgw_dst) as wf:
        A, D, B, E, C, F = [float(wf.readline()) for _ in range(6)]
    for palm in palms:
        x_geo, y_geo = palm["real_coordinates"]["x"], palm["real_coordinates"]["y"]
        w = palm["bbox_pixel"]["width"]
        h = palm["bbox_pixel"]["height"]
        x_px = int((x_geo - C) / A)
        y_px = int((y_geo - F) / E)
        draw.rectangle([(x_px - w//2, y_px - h//2), (x_px + w//2, y_px + h//2)], outline="red", width=2)
    img.save(os.path.join(folder, "with_bbox", image_name))

# 🔧 USO:
# Asumiendo que `folders`, `ambiente_classes`, y `palmera_classes` ya están definidos en tu entorno
nuevo_box_size = 50  # Cambia esto según necesites
modificar_todos_los_labels(folders, nuevo_box_size, ambiente_classes, palmera_classes)
# Out:
# 🛠 Procesando conjunto: TRAIN
# ✅ Anotaciones actualizadas en TRAIN.
#
# 🛠 Procesando conjunto: VAL
# ✅ Anotaciones actualizadas en VAL.
#
# 🛠 Procesando conjunto: TEST
# ✅ Anotaciones actualizadas en TEST.

# %%
folders = {
    #"train": os.path.join(output_folder, "Train"),
    #"val": os.path.join(output_folder, "Val"),
    "test": os.path.join(output_folder, "Test")
}

for folder in folders.values():
    os.makedirs(os.path.join(folder, "images"), exist_ok=True)
    os.makedirs(os.path.join(folder, "labels_ambiente"), exist_ok=True)
    os.makedirs(os.path.join(folder, "labels_palmera"), exist_ok=True)
    os.makedirs(os.path.join(folder, "labels_binaria"), exist_ok=True)
    os.makedirs(os.path.join(folder, "json_annotations"), exist_ok=True)
    os.makedirs(os.path.join(folder, "with_bbox"), exist_ok=True)
    os.makedirs(os.path.join(folder, "worldfiles"), exist_ok=True)
    os.makedirs(os.path.join(folder, "label_number_class"), exist_ok=True)

# --- Inicialización de ArcGIS ---
project = arcpy.mp.ArcGISProject("CURRENT")
map_view = project.activeView
camera = map_view.camera
sr_utm = arcpy.SpatialReference(32628)
camera.spatialReference = sr_utm
map_view.camera = camera

# --- Cargar y convertir el shapefile ---
data = data.to_crs(epsg=32628) if data.crs.to_epsg() != 32628 else data
islas = {"train": "GRAN CANARIA", 
         "val": "TENERIFE", 
         "test": "LA GOMERA"}
data_split = {k: data[data["ISLA"] == v].copy() for k, v in islas.items()}

# --- Crear diccionarios de clases ---
data_gc = data_split["train"]
data_gc["Hibrid"] = data_gc["Hibrid"].fillna("pc")
ambiente_classes = {k: i for i, k in enumerate(sorted(data_gc["Tip_amb"].dropna().unique()))}
palmera_classes = {k: i for i, k in enumerate(sorted(data_gc["Hibrid"].unique()))}

# --- Guardar las clases ---
for subset, folder in folders.items():
    with open(os.path.join(folder, "labels_ambiente", "labels.txt"), "w", encoding="utf-8") as f:
        for name in ambiente_classes:
            f.write(f"{name}\n")
    with open(os.path.join(folder, "labels_palmera", "labels.txt"), "w", encoding="utf-8") as f:
        for name in palmera_classes:
            f.write(f"{name}\n")
    with open(os.path.join(folder, "labels_binaria", "labels.txt"), "w", encoding="utf-8") as f:
        f.write("palmera\n")
    with open(os.path.join(folder, "label_number_class", "ambiente_classes.txt"), "w", encoding="utf-8") as f:
        for name, idx in ambiente_classes.items():
            f.write(f"{idx}: {name}\n")
    with open(os.path.join(folder, "label_number_class", "palmera_classes.txt"), "w", encoding="utf-8") as f:
        for name, idx in palmera_classes.items():
            f.write(f"{idx}: {name}\n")

# --- Parámetros comunes ---
resolution_m_per_px = 0.25
box_size = 30
map_scale = 1000

# --- Funciones auxiliares ---
def export_annotation(image_name, palms, extent, width, height, folder):
    json_path = os.path.join(folder, "json_annotations", image_name.replace(".png", ".json"))
    with open(json_path, "w", encoding="utf-8") as jf:
        json.dump({"image": image_name, "extent": extent.JSON, "palms": palms}, jf, indent=4)

    label_path_amb = os.path.join(folder, "labels_ambiente", image_name.replace(".png", ".txt"))
    label_path_hyb = os.path.join(folder, "labels_palmera", image_name.replace(".png", ".txt"))
    label_path_bin = os.path.join(folder, "labels_binaria", image_name.replace(".png", ".txt"))

    # Mover worldfile
    pgw_path = image_name.replace(".png", ".pgw")
    pgw_src = os.path.join(folder, "images", pgw_path)
    pgw_dst = os.path.join(folder, "worldfiles", pgw_path)
    if os.path.exists(pgw_src):
        os.replace(pgw_src, pgw_dst)

    with open(label_path_amb, "w", encoding="utf-8") as f_amb, \
         open(label_path_hyb, "w", encoding="utf-8") as f_hyb, \
         open(label_path_bin, "w", encoding="utf-8") as f_bin:
        with open(pgw_dst) as wf:
            A, D, B, E, C, F = [float(wf.readline()) for _ in range(6)]

        for palm in palms:
            x_geo, y_geo = palm["real_coordinates"]["x"], palm["real_coordinates"]["y"]
            w, h = palm["bbox_pixel"]["width"], palm["bbox_pixel"]["height"]
            x_px = int((x_geo - C) / A)
            y_px = int((y_geo - F) / E)
            x_norm = float(x_px) / width
            y_norm = float(y_px) / height
            w_norm = float(w) / width
            h_norm = float(h) / height

            amb = ambiente_classes.get(palm["attributes"].get("Tip_amb"), -1)
            hyb = palmera_classes.get(palm["attributes"].get("Hibrid", "pc"), -1)

            if amb != -1:
                f_amb.write(f"{amb} {x_norm:.6f} {y_norm:.6f} {w_norm:.6f} {h_norm:.6f}\n")
            if hyb != -1:
                f_hyb.write(f"{hyb} {x_norm:.6f} {y_norm:.6f} {w_norm:.6f} {h_norm:.6f}\n")
            f_bin.write(f"0 {x_norm:.6f} {y_norm:.6f} {w_norm:.6f} {h_norm:.6f}\n")

    # Dibujar bbox
    img_path = os.path.join(folder, "images", image_name)
    if os.path.exists(img_path) and os.path.exists(pgw_dst):
        img = Image.open(img_path).copy()
        draw = ImageDraw.Draw(img)
        with open(pgw_dst) as wf:
            A, D, B, E, C, F = [float(wf.readline()) for _ in range(6)]
        for palm in palms:
            x_geo, y_geo = palm["real_coordinates"]["x"], palm["real_coordinates"]["y"]
            w = palm["bbox_pixel"]["width"]
            h = palm["bbox_pixel"]["height"]
            x_px = int((x_geo - C) / A)
            y_px = int((y_geo - F) / E)
            draw.rectangle([(x_px - w//2, y_px - h//2), (x_px + w//2, y_px + h//2)], outline="red", width=2)
        img.save(os.path.join(folder, "with_bbox", image_name))

# --- Función para procesamiento por conjunto ---
def process_island(data_island, folder, max_palms):
    processed = set()
    index = 0
    counter = 0
    while index < len(data_island) and counter < max_palms:
        if keyboard.is_pressed('esc'):
            print("⛔ Ejecución interrumpida manualmente con ESC.")
            break
        
        for offset in range(40):
            if index + offset >= len(data_island):
                break
            row = data_island.iloc[index]
            idx = row.name
            if idx in processed:
                #index += 1
                continue

            camera.X, camera.Y = row.geometry.x, row.geometry.y
            camera.scale = map_scale
            map_view.camera = camera
            time.sleep(1.5)

            extent = map_view.camera.getExtent()
            w_m = extent.XMax - extent.XMin
            h_m = extent.YMax - extent.YMin
            width_px = int(w_m / resolution_m_per_px)
            height_px = int(h_m / resolution_m_per_px)

            image_name = f"palmera_{idx}.png"
            image_path = os.path.join(folder, "images", image_name)
            map_view.exportToPNG(image_path, width_px, height_px, world_file=True)

            box = shapely.geometry.box(extent.XMin, extent.YMin, extent.XMax, extent.YMax)
            palms = []
            for j, palm_row in data_island[data_island.geometry.within(box)].iterrows():
                if j in processed:
                    continue
                x, y = palm_row.geometry.x, palm_row.geometry.y
                x_px = ((x - extent.XMin) / w_m) * width_px
                y_px = ((extent.YMax - y) / h_m) * height_px
                palms.append({
                    "tree_id": j,
                    "real_coordinates": {"x": x, "y": y},
                    "attributes": palm_row.drop("geometry").to_dict(),
                    "bbox_pixel": {""
                        "x_center": int(x_px), 
                        "y_center": int(y_px), 
                        "width": box_size, 
                        "height": box_size
                    },
                    "image_size_px": (width_px, height_px)
                })
                processed.add(j)

        if palms:
            export_annotation(image_name, palms, extent, width_px, height_px, folder)
            counter += len(palms)
        index += 400
    return counter

# --- Ejecutar procesamiento en orden Train/Val/Test ---
#total_gc = process_island(data_split["train"], folders["train"], float("inf"))
total_gc = 146020

# Si las palmeras de gc representan el 70% del total, el total será ese numero más un 30% del mismo
#total_palms_dataset = total_gc + (total_gc * 0.3)
#val_count = int(total_palms_dataset * 0.2)
#test_count = int(total_palms_dataset * 0.1)
#total_tnf = process_island(data_split["val"], folders["val"], val_count)
total_gomera = process_island(data_split["test"], folders["test"], 2067)

print("✅ Dataset completo generado con la estructura Train/Val/Test.")
#print(f"Numero de palmeras de GC: {total_gc}")
#print(f"Numero de palmeras de TNF: {total_tnf}")
print(f"Numero de palmeras de LA GOMERA: {total_gomera}")
#print(f"Numero de palmeras totales: {total_palms_dataset} y suma que debe ser lo mismo {total_gc + total_tnf + total_gomera}")

# --- Mostrar recuento de imágenes y anotaciones YOLO por conjunto ---
def count_annotations(folder_name):
    image_dir = os.path.join(folder_name, "images")
    label_dir = os.path.join(folder_name, "labels_binaria")
    num_images = len([f for f in os.listdir(image_dir) if f.endswith(".png")])
    num_labels = len([f for f in os.listdir(label_dir) if f.endswith(".txt")])
    return num_images, num_labels
# Out:
# ✅ Dataset completo generado con la estructura Train/Val/Test.
# Numero de palmeras de LA GOMERA: 2095

# %% [markdown]
# Given that the existing dataset has not a good variaty of environment samples and many photos appears to be pretty much equal, we will collect new coordinates of palms to extract new images.

# %%
# Cargar las coordenadas de las palmeras
data = gpd.read_file(shapefile_path)

# %%
output_folder = r"F:\Universidad\Curso 2024-25\Segundo Semestre\TFG\Desarrollo\dataset\classification_per_type\environment_classification_dataset"
os.makedirs(output_folder, exist_ok=True)

capture_folder = os.path.join(output_folder, "CapturesRaw")
os.makedirs(capture_folder, exist_ok=True)

folders = {
    "train": os.path.join(output_folder, "Train"),
    "val": os.path.join(output_folder, "Val"),
    "test": os.path.join(output_folder, "Test")
}

islands = ["GRAN CANARIA", "TENERIFE", "LA GOMERA"]

data_islands = data[data["ISLA"].isin(islands)].copy()
data_env = data_islands[data_islands["Tip_amb"].notna()].copy()

# Rellenar los nulos con "pc"
data_islands["Hibrid"] = data_islands["Hibrid"].fillna("pc")
data_type = data_islands.copy()

# Crear diccionarios de clases
env_classes = {k: i for i, k in enumerate(sorted(data_env["Tip_amb"].unique())) if k != "?"}
type_classes = {k: i for i, k in enumerate(sorted(data_type["Hibrid"].unique())) if k != "?"}


print("env_classes: ", env_classes)
print("type_classes: ", type_classes)


# --- Parámetros ---
resolution_m_per_px = 0.25
scale = 1000
img_size = 256
max_per_class = 600
train_folder = folders["train"]

# --- Reproyección ---
data_env = data_env.to_crs(epsg=32628)

# --- ArcGIS setup ---
project = arcpy.mp.ArcGISProject("CURRENT")
map_view = project.activeView
camera = map_view.camera
camera.spatialReference = arcpy.SpatialReference(32628)
map_view.camera = camera

# --- Función para obtener extent desde una palmera ---
def get_extent(row):
    camera.X = row.geometry.x
    camera.Y = row.geometry.y
    camera.scale = scale
    map_view.camera = camera
    time.sleep(0.25)
    return map_view.camera.getExtent()

# --- Bucle por clase de ambiente ---
for ambiente in env_classes.keys():
    print(f"\nProcesando ambiente: {ambiente}")
    clase_df = data_env[data_env["Tip_amb"] == ambiente].copy()
    if clase_df.empty:
        print(f"⚠️ No hay palmeras para el ambiente '{ambiente}'")
        continue

    clase_df = clase_df.sample(frac=1, random_state=42).reset_index()
    used_extents = []
    processed_ids = set()
    saved = 0

    ambiente_folder = os.path.join(capture_folder, ambiente)
    os.makedirs(ambiente_folder, exist_ok=True)

    worldfile_folder = os.path.join(ambiente_folder, "worldfiles")
    os.makedirs(worldfile_folder, exist_ok=True)

    while saved < max_per_class:
        new_captures = 0

        for idx, row in clase_df.iterrows():
            if row["index"] in processed_ids:
                continue

            extent = get_extent(row)
            capture_box = shapely.geometry.box(extent.XMin, extent.YMin, extent.XMax, extent.YMax)

            if any(capture_box.intersects(prev) for prev in used_extents):
                continue

            image_name = f"{ambiente}_{row['index']}.png"
            image_path = os.path.join(ambiente_folder, image_name)
            map_view.exportToPNG(image_path, img_size, img_size, world_file=True)

            # Mover el worldfile a su carpeta
            pgw_src = image_path.replace(".png", ".pgw")
            pgw_dst = os.path.join(worldfile_folder, os.path.basename(pgw_src))
            if os.path.exists(pgw_src):
                shutil.move(pgw_src, pgw_dst)
            else:
                print(f"⚠️ Worldfile no encontrado para: {image_name}")

            used_extents.append(capture_box)
            processed_ids.add(row["index"])
            saved += 1
            new_captures += 1
            print(f"{ambiente} - Captura {saved}/{max_per_class}")

            if saved >= max_per_class:
                break

        if new_captures == 0:
            print(f"No fue posible alcanzar {max_per_class} capturas únicas para la clase '{ambiente}'. Solo se capturaron {saved}.")
            break

    if saved >= max_per_class:
        print(f"Clase '{ambiente}' completada con {saved} capturas únicas.")

# --- División Train/Val/Test ---
print("\nDividiendo capturas en Train / Val / Test...")
# Out:
# env_classes:  {'na': 1, 'ot': 2, 'rd': 3, 'ru': 4, 'ud': 5, 'uj': 6, 'vi': 7}
# type_classes:  {'bdc': 1, 'da': 2, 'hme': 3, 'pc': 4, 'pme': 5, 'tdi': 6}
#
# 🌴 Procesando ambiente: na
# ✅ na - Captura 1/600
# ✅ na - Captura 2/600
# ✅ na - Captura 3/600
# ✅ na - Captura 4/600
# ✅ na - Captura 5/600
# ✅ na - Captura 6/600
# ✅ na - Captura 7/600
# ✅ na - Captura 8/600
# ✅ na - Captura 9/600
# ✅ na - Captura 10/600
# ✅ na - Captura 11/600
# ✅ na - Captura 12/600
# ✅ na - Captura 13/600
# ✅ na - Captura 14/600
# ✅ na - Captura 15/600
# ✅ na - Captura 16/600
# ✅ na - Captura 17/600
# ✅ na - Captura 18/600
# ✅ na - Captura 19/600
# ✅ na - Captura 20/600
# ✅ na - Captura 21/600
# ✅ na - Captura 22/600
# ✅ na - Captura 23/600
# ✅ na - Captura 24/600
# ✅ na - Captura 25/600
# ✅ na - Captura 26/600
# ✅ na - Captura 27/600
# ✅ na - Captura 28/600
# ✅ na - Captura 29/600
# ✅ na - Captura 30/600
# ✅ na - Captura 31/600
# ✅ na - Captura 32/600
# ✅ na - Captura 33/600
# ✅ na - Captura 34/600
# ✅ na - Captura 35/600
# ✅ na - Captura 36/600
# ✅ na - Captura 37/600
# ✅ na - Captura 38/600
# ✅ na - Captura 39/600
# ✅ na - Captura 40/600
# ✅ na - Captura 41/600
# ✅ na - Captura 42/600
# ✅ na - Captura 43/600
# ✅ na - Captura 44/600
# ✅ na - Captura 45/600
# ✅ na - Captura 46/600
# ✅ na - Captura 47/600
# ✅ na - Captura 48/600
# ✅ na - Captura 49/600
# ✅ na - Captura 50/600
# ✅ na - Captura 51/600
# ✅ na - Captura 52/600
# ✅ na - Captura 53/600
# ✅ na - Captura 54/600
# ✅ na - Captura 55/600
# ✅ na - Captura 56/600
# ✅ na - Captura 57/600
# ✅ na - Captura 58/600
# ✅ na - Captura 59/600
# ✅ na - Captura 60/600
# ✅ na - Captura 61/600
# ✅ na - Captura 62/600
# ✅ na - Captura 63/600
# ✅ na - Captura 64/600
# ✅ na - Captura 65/600
# ✅ na - Captura 66/600
# ✅ na - Captura 67/600
# ✅ na - Captura 68/600
# ✅ na - Captura 69/600
# ✅ na - Captura 70/600
# ✅ na - Captura 71/600
# ✅ na - Captura 72/600
# ✅ na - Captura 73/600
# ✅ na - Captura 74/600
# ✅ na - Captura 75/600
# ✅ na - Captura 76/600
# ✅ na - Captura 77/600
# ✅ na - Captura 78/600
# ✅ na - Captura 79/600
# ✅ na - Captura 80/600
# ✅ na - Captura 81/600
# ✅ na - Captura 82/600
# ✅ na - Captura 83/600
# ✅ na - Captura 84/600
# ✅ na - Captura 85/600
# ✅ na - Captura 86/600
# ✅ na - Captura 87/600
# ✅ na - Captura 88/600
# ✅ na - Captura 89/600
# ✅ na - Captura 90/600
# ✅ na - Captura 91/600
# ✅ na - Captura 92/600
# ✅ na - Captura 93/600
# ✅ na - Captura 94/600
# ✅ na - Captura 95/600
# ✅ na - Captura 96/600
# ✅ na - Captura 97/600
# ✅ na - Captura 98/600
# ✅ na - Captura 99/600
# ✅ na - Captura 100/600
# ✅ na - Captura 101/600
# ✅ na - Captura 102/600
# ✅ na - Captura 103/600
# ✅ na - Captura 104/600
# ✅ na - Captura 105/600
# ✅ na - Captura 106/600
# ✅ na - Captura 107/600
# ✅ na - Captura 108/600
# ✅ na - Captura 109/600
# ✅ na - Captura 110/600
# ✅ na - Captura 111/600
# ✅ na - Captura 112/600
# ✅ na - Captura 113/600
# ✅ na - Captura 114/600
# ✅ na - Captura 115/600
# ✅ na - Captura 116/600
# ✅ na - Captura 117/600
# ✅ na - Captura 118/600
# ✅ na - Captura 119/600
# ✅ na - Captura 120/600
# ✅ na - Captura 121/600
# ✅ na - Captura 122/600
# ✅ na - Captura 123/600
# ✅ na - Captura 124/600
# ✅ na - Captura 125/600
# ✅ na - Captura 126/600
# ✅ na - Captura 127/600
# ✅ na - Captura 128/600
# ✅ na - Captura 129/600
# ✅ na - Captura 130/600
# ✅ na - Captura 131/600
# ✅ na - Captura 132/600
# ✅ na - Captura 133/600
# ✅ na - Captura 134/600
# ✅ na - Captura 135/600
# ✅ na - Captura 136/600
# ✅ na - Captura 137/600
# ✅ na - Captura 138/600
# ✅ na - Captura 139/600
# ✅ na - Captura 140/600
# ✅ na - Captura 141/600
# ✅ na - Captura 142/600
# ✅ na - Captura 143/600
# ✅ na - Captura 144/600
# ✅ na - Captura 145/600
# ✅ na - Captura 146/600
# ✅ na - Captura 147/600
# ✅ na - Captura 148/600
# ✅ na - Captura 149/600
# ✅ na - Captura 150/600
# ✅ na - Captura 151/600
# ✅ na - Captura 152/600
# ✅ na - Captura 153/600
# ✅ na - Captura 154/600
# ✅ na - Captura 155/600
# ✅ na - Captura 156/600
# ✅ na - Captura 157/600
# ✅ na - Captura 158/600
# ✅ na - Captura 159/600
# ✅ na - Captura 160/600
# ✅ na - Captura 161/600
# ✅ na - Captura 162/600
# ✅ na - Captura 163/600
# ✅ na - Captura 164/600
# ✅ na - Captura 165/600
# ✅ na - Captura 166/600
# ✅ na - Captura 167/600
# ✅ na - Captura 168/600
# ✅ na - Captura 169/600
# ✅ na - Captura 170/600
# ✅ na - Captura 171/600
# ✅ na - Captura 172/600
# ✅ na - Captura 173/600
# ✅ na - Captura 174/600
# ✅ na - Captura 175/600
# ✅ na - Captura 176/600
# ✅ na - Captura 177/600
# ✅ na - Captura 178/600
# ✅ na - Captura 179/600
# ✅ na - Captura 180/600
# ✅ na - Captura 181/600
# ✅ na - Captura 182/600
# ✅ na - Captura 183/600
# ✅ na - Captura 184/600
# ✅ na - Captura 185/600
# ✅ na - Captura 186/600
# ✅ na - Captura 187/600
# ✅ na - Captura 188/600
# ✅ na - Captura 189/600
# ✅ na - Captura 190/600
# ✅ na - Captura 191/600
# ✅ na - Captura 192/600
# ✅ na - Captura 193/600
# ✅ na - Captura 194/600
# ✅ na - Captura 195/600
# ✅ na - Captura 196/600
# ✅ na - Captura 197/600
# ✅ na - Captura 198/600
# ✅ na - Captura 199/600
# ✅ na - Captura 200/600
# ✅ na - Captura 201/600
# ✅ na - Captura 202/600
# ✅ na - Captura 203/600
# ✅ na - Captura 204/600
# ✅ na - Captura 205/600
# ✅ na - Captura 206/600
# ✅ na - Captura 207/600
# ✅ na - Captura 208/600
# ✅ na - Captura 209/600
# ✅ na - Captura 210/600
# ✅ na - Captura 211/600
# ✅ na - Captura 212/600
# ✅ na - Captura 213/600
# ✅ na - Captura 214/600
# ✅ na - Captura 215/600
# ✅ na - Captura 216/600
# ✅ na - Captura 217/600
# ✅ na - Captura 218/600
# ✅ na - Captura 219/600
# ✅ na - Captura 220/600
# ✅ na - Captura 221/600
# ✅ na - Captura 222/600
# ✅ na - Captura 223/600
# ✅ na - Captura 224/600
# ✅ na - Captura 225/600
# ✅ na - Captura 226/600
# ✅ na - Captura 227/600
# ✅ na - Captura 228/600
# ✅ na - Captura 229/600
# ✅ na - Captura 230/600
# ✅ na - Captura 231/600
# ✅ na - Captura 232/600
# ✅ na - Captura 233/600
# ✅ na - Captura 234/600
# ✅ na - Captura 235/600
# ✅ na - Captura 236/600
# ✅ na - Captura 237/600
# ✅ na - Captura 238/600
# ✅ na - Captura 239/600
# ✅ na - Captura 240/600
# ✅ na - Captura 241/600
# ✅ na - Captura 242/600
# ✅ na - Captura 243/600
# ✅ na - Captura 244/600
# ✅ na - Captura 245/600
# ✅ na - Captura 246/600
# ✅ na - Captura 247/600
# ✅ na - Captura 248/600
# ✅ na - Captura 249/600
# ✅ na - Captura 250/600
# ✅ na - Captura 251/600
# ✅ na - Captura 252/600
# ✅ na - Captura 253/600
# ✅ na - Captura 254/600
# ✅ na - Captura 255/600
# ✅ na - Captura 256/600
# ✅ na - Captura 257/600
# ✅ na - Captura 258/600
# ✅ na - Captura 259/600
# ✅ na - Captura 260/600
# ✅ na - Captura 261/600
# ✅ na - Captura 262/600
# ✅ na - Captura 263/600
# ✅ na - Captura 264/600
# ✅ na - Captura 265/600
# ✅ na - Captura 266/600
# ✅ na - Captura 267/600
# ✅ na - Captura 268/600
# ✅ na - Captura 269/600
# ✅ na - Captura 270/600
# ✅ na - Captura 271/600
# ✅ na - Captura 272/600
# ✅ na - Captura 273/600
# ✅ na - Captura 274/600
# ✅ na - Captura 275/600
# ✅ na - Captura 276/600
# ✅ na - Captura 277/600
# ✅ na - Captura 278/600
# ✅ na - Captura 279/600
# ✅ na - Captura 280/600
# ✅ na - Captura 281/600
# ✅ na - Captura 282/600
# ✅ na - Captura 283/600
# ✅ na - Captura 284/600
# ✅ na - Captura 285/600
# ✅ na - Captura 286/600
# ✅ na - Captura 287/600
# ✅ na - Captura 288/600
# ✅ na - Captura 289/600
# ✅ na - Captura 290/600
# ✅ na - Captura 291/600
# ✅ na - Captura 292/600
# ✅ na - Captura 293/600
# ✅ na - Captura 294/600
# ✅ na - Captura 295/600
# ✅ na - Captura 296/600
# ✅ na - Captura 297/600
# ✅ na - Captura 298/600
# ✅ na - Captura 299/600
# ✅ na - Captura 300/600
# ✅ na - Captura 301/600
# ✅ na - Captura 302/600
# ✅ na - Captura 303/600
# ✅ na - Captura 304/600
# ✅ na - Captura 305/600
# ✅ na - Captura 306/600
# ✅ na - Captura 307/600
# ✅ na - Captura 308/600
# ✅ na - Captura 309/600
# ✅ na - Captura 310/600
# ✅ na - Captura 311/600
# ✅ na - Captura 312/600
# ✅ na - Captura 313/600
# ✅ na - Captura 314/600
# ✅ na - Captura 315/600
# ✅ na - Captura 316/600
# ✅ na - Captura 317/600
# ✅ na - Captura 318/600
# ✅ na - Captura 319/600
# ✅ na - Captura 320/600
# ✅ na - Captura 321/600
# ✅ na - Captura 322/600
# ✅ na - Captura 323/600
# ✅ na - Captura 324/600
# ✅ na - Captura 325/600
# ✅ na - Captura 326/600
# ✅ na - Captura 327/600
# ✅ na - Captura 328/600
# ✅ na - Captura 329/600
# ✅ na - Captura 330/600
# ✅ na - Captura 331/600
# ✅ na - Captura 332/600
# ✅ na - Captura 333/600
# ✅ na - Captura 334/600
# ✅ na - Captura 335/600
# ✅ na - Captura 336/600
# ✅ na - Captura 337/600
# ✅ na - Captura 338/600
# ✅ na - Captura 339/600
# ✅ na - Captura 340/600
# ✅ na - Captura 341/600
# ✅ na - Captura 342/600
# ✅ na - Captura 343/600
# ✅ na - Captura 344/600
# ✅ na - Captura 345/600
# ✅ na - Captura 346/600
# ✅ na - Captura 347/600
# ✅ na - Captura 348/600
# ✅ na - Captura 349/600
# ✅ na - Captura 350/600
# ✅ na - Captura 351/600
# ✅ na - Captura 352/600
# ✅ na - Captura 353/600
# ✅ na - Captura 354/600
# ✅ na - Captura 355/600
# ✅ na - Captura 356/600
# ✅ na - Captura 357/600
# ✅ na - Captura 358/600
# ✅ na - Captura 359/600
# ✅ na - Captura 360/600
# ✅ na - Captura 361/600
# ✅ na - Captura 362/600
# ✅ na - Captura 363/600
# ✅ na - Captura 364/600
# ✅ na - Captura 365/600
# ✅ na - Captura 366/600
# ✅ na - Captura 367/600
# ✅ na - Captura 368/600
# ✅ na - Captura 369/600
# ✅ na - Captura 370/600
# ✅ na - Captura 371/600
# ✅ na - Captura 372/600
# ✅ na - Captura 373/600
# ✅ na - Captura 374/600
# ✅ na - Captura 375/600
# ✅ na - Captura 376/600
# ✅ na - Captura 377/600
# ✅ na - Captura 378/600
# ✅ na - Captura 379/600
# ✅ na - Captura 380/600
# ✅ na - Captura 381/600
# ✅ na - Captura 382/600
# ✅ na - Captura 383/600
# ✅ na - Captura 384/600
# ✅ na - Captura 385/600
# ✅ na - Captura 386/600
# ✅ na - Captura 387/600
# ✅ na - Captura 388/600
# ✅ na - Captura 389/600
# ✅ na - Captura 390/600
# ✅ na - Captura 391/600
# ✅ na - Captura 392/600
# ✅ na - Captura 393/600
# ✅ na - Captura 394/600
# ✅ na - Captura 395/600
# ✅ na - Captura 396/600
# ✅ na - Captura 397/600
# ✅ na - Captura 398/600
# ✅ na - Captura 399/600
# ✅ na - Captura 400/600
# ✅ na - Captura 401/600
# ✅ na - Captura 402/600
# ✅ na - Captura 403/600
# ✅ na - Captura 404/600
# ✅ na - Captura 405/600
# ✅ na - Captura 406/600
# ✅ na - Captura 407/600
# ✅ na - Captura 408/600
# ✅ na - Captura 409/600
# ✅ na - Captura 410/600
# ✅ na - Captura 411/600
# ✅ na - Captura 412/600
# ✅ na - Captura 413/600
# ✅ na - Captura 414/600
# ✅ na - Captura 415/600
# ✅ na - Captura 416/600
# ✅ na - Captura 417/600
# ✅ na - Captura 418/600
# ✅ na - Captura 419/600
# ✅ na - Captura 420/600
# ✅ na - Captura 421/600
# ✅ na - Captura 422/600
# ✅ na - Captura 423/600
# ✅ na - Captura 424/600
# ✅ na - Captura 425/600
# ✅ na - Captura 426/600
# ✅ na - Captura 427/600
# ✅ na - Captura 428/600
# ✅ na - Captura 429/600
# ✅ na - Captura 430/600
# ✅ na - Captura 431/600
# ✅ na - Captura 432/600
# ✅ na - Captura 433/600
# ✅ na - Captura 434/600
# ✅ na - Captura 435/600
# ✅ na - Captura 436/600
# ✅ na - Captura 437/600
# ✅ na - Captura 438/600
# ✅ na - Captura 439/600
# ✅ na - Captura 440/600
# ✅ na - Captura 441/600
# ✅ na - Captura 442/600
# ✅ na - Captura 443/600
# ✅ na - Captura 444/600
# ✅ na - Captura 445/600
# ✅ na - Captura 446/600
# ✅ na - Captura 447/600
# ✅ na - Captura 448/600
# ✅ na - Captura 449/600
# ✅ na - Captura 450/600
# ✅ na - Captura 451/600
# ✅ na - Captura 452/600
# ✅ na - Captura 453/600
# ✅ na - Captura 454/600
# ✅ na - Captura 455/600
# ✅ na - Captura 456/600
# ✅ na - Captura 457/600
# ✅ na - Captura 458/600
# ✅ na - Captura 459/600
# ✅ na - Captura 460/600
# ✅ na - Captura 461/600
# ✅ na - Captura 462/600
# ✅ na - Captura 463/600
# ✅ na - Captura 464/600
# ✅ na - Captura 465/600
# ✅ na - Captura 466/600
# ✅ na - Captura 467/600
# ✅ na - Captura 468/600
# ✅ na - Captura 469/600
# ✅ na - Captura 470/600
# ✅ na - Captura 471/600
# ✅ na - Captura 472/600
# ✅ na - Captura 473/600
# ✅ na - Captura 474/600
# ✅ na - Captura 475/600
# ✅ na - Captura 476/600
# ✅ na - Captura 477/600
# ✅ na - Captura 478/600
# ✅ na - Captura 479/600
# ✅ na - Captura 480/600
# ✅ na - Captura 481/600
# ✅ na - Captura 482/600
# ✅ na - Captura 483/600
# ✅ na - Captura 484/600
# ✅ na - Captura 485/600
# ✅ na - Captura 486/600
# ✅ na - Captura 487/600
# ✅ na - Captura 488/600
# ✅ na - Captura 489/600
# ✅ na - Captura 490/600
# ✅ na - Captura 491/600
# ✅ na - Captura 492/600
# ✅ na - Captura 493/600
# ✅ na - Captura 494/600
# ✅ na - Captura 495/600
# ✅ na - Captura 496/600
# ✅ na - Captura 497/600
# ✅ na - Captura 498/600
# ✅ na - Captura 499/600
# ✅ na - Captura 500/600
# ✅ na - Captura 501/600
# ✅ na - Captura 502/600
# ✅ na - Captura 503/600
# ✅ na - Captura 504/600
# ✅ na - Captura 505/600
# ✅ na - Captura 506/600
# ✅ na - Captura 507/600
# ✅ na - Captura 508/600
# ✅ na - Captura 509/600
# ✅ na - Captura 510/600
# ✅ na - Captura 511/600
# ✅ na - Captura 512/600
# ✅ na - Captura 513/600
# ✅ na - Captura 514/600
# ✅ na - Captura 515/600
# ✅ na - Captura 516/600
# ✅ na - Captura 517/600
# ✅ na - Captura 518/600
# ✅ na - Captura 519/600
# ✅ na - Captura 520/600
# ✅ na - Captura 521/600
# ✅ na - Captura 522/600
# ✅ na - Captura 523/600
# ✅ na - Captura 524/600
# ✅ na - Captura 525/600
# ✅ na - Captura 526/600
# ✅ na - Captura 527/600
# ✅ na - Captura 528/600
# ✅ na - Captura 529/600
# ✅ na - Captura 530/600
# ✅ na - Captura 531/600
# ✅ na - Captura 532/600
# ✅ na - Captura 533/600
# ✅ na - Captura 534/600
# ✅ na - Captura 535/600
# ✅ na - Captura 536/600
# ✅ na - Captura 537/600
# ✅ na - Captura 538/600
# ✅ na - Captura 539/600
# ✅ na - Captura 540/600
# ✅ na - Captura 541/600
# ✅ na - Captura 542/600
# ✅ na - Captura 543/600
# ✅ na - Captura 544/600
# ✅ na - Captura 545/600
# ✅ na - Captura 546/600
# ✅ na - Captura 547/600
# ✅ na - Captura 548/600
# ✅ na - Captura 549/600
# ✅ na - Captura 550/600
# ✅ na - Captura 551/600
# ✅ na - Captura 552/600
# ✅ na - Captura 553/600
# ✅ na - Captura 554/600
# ✅ na - Captura 555/600
# ✅ na - Captura 556/600
# ✅ na - Captura 557/600
# ✅ na - Captura 558/600
# ✅ na - Captura 559/600
# ✅ na - Captura 560/600
# ✅ na - Captura 561/600
# ✅ na - Captura 562/600
# ✅ na - Captura 563/600
# ✅ na - Captura 564/600
# ✅ na - Captura 565/600
# ✅ na - Captura 566/600
# ✅ na - Captura 567/600
# ✅ na - Captura 568/600
# ✅ na - Captura 569/600
# ✅ na - Captura 570/600
# ✅ na - Captura 571/600
# ✅ na - Captura 572/600
# ✅ na - Captura 573/600
# ✅ na - Captura 574/600
# ✅ na - Captura 575/600
# ✅ na - Captura 576/600
# ✅ na - Captura 577/600
# ✅ na - Captura 578/600
# ✅ na - Captura 579/600
# ✅ na - Captura 580/600
# ✅ na - Captura 581/600
# ✅ na - Captura 582/600
# ✅ na - Captura 583/600
# ✅ na - Captura 584/600
# ✅ na - Captura 585/600
# ✅ na - Captura 586/600
# ✅ na - Captura 587/600
# ✅ na - Captura 588/600
# ✅ na - Captura 589/600
# ✅ na - Captura 590/600
# ✅ na - Captura 591/600
# ✅ na - Captura 592/600
# ✅ na - Captura 593/600
# ✅ na - Captura 594/600
# ✅ na - Captura 595/600
# ✅ na - Captura 596/600
# ✅ na - Captura 597/600
# ✅ na - Captura 598/600
# ✅ na - Captura 599/600
# ✅ na - Captura 600/600
# 🎉 Clase 'na' completada con 600 capturas únicas.
#
# 🌴 Procesando ambiente: ot
# ✅ ot - Captura 1/600
# ✅ ot - Captura 2/600
# ✅ ot - Captura 3/600
# ✅ ot - Captura 4/600
# ✅ ot - Captura 5/600
# ✅ ot - Captura 6/600
# ✅ ot - Captura 7/600
# ✅ ot - Captura 8/600
# ✅ ot - Captura 9/600
# ✅ ot - Captura 10/600
# ✅ ot - Captura 11/600
# ✅ ot - Captura 12/600
# ✅ ot - Captura 13/600
# ✅ ot - Captura 14/600
# ✅ ot - Captura 15/600
# ✅ ot - Captura 16/600
# ✅ ot - Captura 17/600
# ✅ ot - Captura 18/600
# ✅ ot - Captura 19/600
# ✅ ot - Captura 20/600
# ✅ ot - Captura 21/600
# ✅ ot - Captura 22/600
# ✅ ot - Captura 23/600
# ✅ ot - Captura 24/600
# ✅ ot - Captura 25/600
# ✅ ot - Captura 26/600
# ✅ ot - Captura 27/600
# ✅ ot - Captura 28/600
# ✅ ot - Captura 29/600
# ✅ ot - Captura 30/600
# ✅ ot - Captura 31/600
# ✅ ot - Captura 32/600
# ✅ ot - Captura 33/600
# ✅ ot - Captura 34/600
# ✅ ot - Captura 35/600
# ✅ ot - Captura 36/600
# ✅ ot - Captura 37/600
# ✅ ot - Captura 38/600
# ✅ ot - Captura 39/600
# ✅ ot - Captura 40/600
# ✅ ot - Captura 41/600
# ✅ ot - Captura 42/600
# ✅ ot - Captura 43/600
# ✅ ot - Captura 44/600
# ✅ ot - Captura 45/600
# ✅ ot - Captura 46/600
# ✅ ot - Captura 47/600
# ✅ ot - Captura 48/600
# ✅ ot - Captura 49/600
# ✅ ot - Captura 50/600
# ✅ ot - Captura 51/600
# ✅ ot - Captura 52/600
# ✅ ot - Captura 53/600
# ✅ ot - Captura 54/600
# ✅ ot - Captura 55/600
# ✅ ot - Captura 56/600
# ✅ ot - Captura 57/600
# ✅ ot - Captura 58/600
# ✅ ot - Captura 59/600
# ✅ ot - Captura 60/600
# ✅ ot - Captura 61/600
# ✅ ot - Captura 62/600
# ✅ ot - Captura 63/600
# ✅ ot - Captura 64/600
# ✅ ot - Captura 65/600
# ✅ ot - Captura 66/600
# ✅ ot - Captura 67/600
# ✅ ot - Captura 68/600
# ✅ ot - Captura 69/600
# ✅ ot - Captura 70/600
# ✅ ot - Captura 71/600
# ✅ ot - Captura 72/600
# ✅ ot - Captura 73/600
# ✅ ot - Captura 74/600
# ✅ ot - Captura 75/600
# ✅ ot - Captura 76/600
# ✅ ot - Captura 77/600
# ✅ ot - Captura 78/600
# ✅ ot - Captura 79/600
# ✅ ot - Captura 80/600
# ✅ ot - Captura 81/600
# ✅ ot - Captura 82/600
# ✅ ot - Captura 83/600
# ✅ ot - Captura 84/600
# ✅ ot - Captura 85/600
# ✅ ot - Captura 86/600
# ✅ ot - Captura 87/600
# ✅ ot - Captura 88/600
# ✅ ot - Captura 89/600
# ✅ ot - Captura 90/600
# ✅ ot - Captura 91/600
# ✅ ot - Captura 92/600
# ✅ ot - Captura 93/600
# ✅ ot - Captura 94/600
# ✅ ot - Captura 95/600
# ✅ ot - Captura 96/600
# ✅ ot - Captura 97/600
# ✅ ot - Captura 98/600
# ✅ ot - Captura 99/600
# ✅ ot - Captura 100/600
# ✅ ot - Captura 101/600
# ✅ ot - Captura 102/600
# ✅ ot - Captura 103/600
# ✅ ot - Captura 104/600
# ✅ ot - Captura 105/600
# ✅ ot - Captura 106/600
# ✅ ot - Captura 107/600
# ✅ ot - Captura 108/600
# ✅ ot - Captura 109/600
# ✅ ot - Captura 110/600
# ✅ ot - Captura 111/600
# ✅ ot - Captura 112/600
# ✅ ot - Captura 113/600
# ✅ ot - Captura 114/600
# ✅ ot - Captura 115/600
# ✅ ot - Captura 116/600
# ✅ ot - Captura 117/600
# ✅ ot - Captura 118/600
# ✅ ot - Captura 119/600
# ✅ ot - Captura 120/600
# ✅ ot - Captura 121/600
# ✅ ot - Captura 122/600
# ✅ ot - Captura 123/600
# ✅ ot - Captura 124/600
# ✅ ot - Captura 125/600
# ✅ ot - Captura 126/600
# ✅ ot - Captura 127/600
# ✅ ot - Captura 128/600
# ✅ ot - Captura 129/600
# ✅ ot - Captura 130/600
# ✅ ot - Captura 131/600
# ✅ ot - Captura 132/600
# ✅ ot - Captura 133/600
# ✅ ot - Captura 134/600
# ✅ ot - Captura 135/600
# ✅ ot - Captura 136/600
# ✅ ot - Captura 137/600
# ✅ ot - Captura 138/600
# ✅ ot - Captura 139/600
# ✅ ot - Captura 140/600
# ✅ ot - Captura 141/600
# ✅ ot - Captura 142/600
# ✅ ot - Captura 143/600
# ✅ ot - Captura 144/600
# ✅ ot - Captura 145/600
# ✅ ot - Captura 146/600
# ✅ ot - Captura 147/600
# ✅ ot - Captura 148/600
# ✅ ot - Captura 149/600
# ✅ ot - Captura 150/600
# ✅ ot - Captura 151/600
# ✅ ot - Captura 152/600
# ✅ ot - Captura 153/600
# ✅ ot - Captura 154/600
# ✅ ot - Captura 155/600
# ✅ ot - Captura 156/600
# ✅ ot - Captura 157/600
# ✅ ot - Captura 158/600
# ✅ ot - Captura 159/600
# ✅ ot - Captura 160/600
# ✅ ot - Captura 161/600
# ✅ ot - Captura 162/600
# ✅ ot - Captura 163/600
# ✅ ot - Captura 164/600
# ✅ ot - Captura 165/600
# ✅ ot - Captura 166/600
# ✅ ot - Captura 167/600
# ✅ ot - Captura 168/600
# ✅ ot - Captura 169/600
# ✅ ot - Captura 170/600
# ✅ ot - Captura 171/600
# ✅ ot - Captura 172/600
# ✅ ot - Captura 173/600
# ✅ ot - Captura 174/600
# ✅ ot - Captura 175/600
# ✅ ot - Captura 176/600
# ✅ ot - Captura 177/600
# ✅ ot - Captura 178/600
# ✅ ot - Captura 179/600
# ✅ ot - Captura 180/600
# ✅ ot - Captura 181/600
# ✅ ot - Captura 182/600
# ✅ ot - Captura 183/600
# ✅ ot - Captura 184/600
# ✅ ot - Captura 185/600
# ✅ ot - Captura 186/600
# ✅ ot - Captura 187/600
# ✅ ot - Captura 188/600
# ✅ ot - Captura 189/600
# ✅ ot - Captura 190/600
# ✅ ot - Captura 191/600
# ✅ ot - Captura 192/600
# ✅ ot - Captura 193/600
# ✅ ot - Captura 194/600
# ✅ ot - Captura 195/600
# ✅ ot - Captura 196/600
# ✅ ot - Captura 197/600
# ✅ ot - Captura 198/600
# ✅ ot - Captura 199/600
# ✅ ot - Captura 200/600
# ✅ ot - Captura 201/600
# ✅ ot - Captura 202/600
# ✅ ot - Captura 203/600
# ✅ ot - Captura 204/600
# ✅ ot - Captura 205/600
# ✅ ot - Captura 206/600
# ✅ ot - Captura 207/600
# ✅ ot - Captura 208/600
# ✅ ot - Captura 209/600
# ✅ ot - Captura 210/600
# ✅ ot - Captura 211/600
# ✅ ot - Captura 212/600
# ✅ ot - Captura 213/600
# ✅ ot - Captura 214/600
# ✅ ot - Captura 215/600
# ✅ ot - Captura 216/600
# ✅ ot - Captura 217/600
# ✅ ot - Captura 218/600
# ✅ ot - Captura 219/600
# ✅ ot - Captura 220/600
# ✅ ot - Captura 221/600
# ✅ ot - Captura 222/600
# ✅ ot - Captura 223/600
# ✅ ot - Captura 224/600
# ✅ ot - Captura 225/600
# ✅ ot - Captura 226/600
# ✅ ot - Captura 227/600
# ✅ ot - Captura 228/600
# ✅ ot - Captura 229/600
# ✅ ot - Captura 230/600
# ✅ ot - Captura 231/600
# ✅ ot - Captura 232/600
# ✅ ot - Captura 233/600
# ✅ ot - Captura 234/600
# ✅ ot - Captura 235/600
# ✅ ot - Captura 236/600
# ✅ ot - Captura 237/600
# ✅ ot - Captura 238/600
# ✅ ot - Captura 239/600
# ✅ ot - Captura 240/600
# ✅ ot - Captura 241/600
# ✅ ot - Captura 242/600
# ⚠️ No fue posible alcanzar 600 capturas únicas para la clase 'ot'. Solo se capturaron 242.
#
# 🌴 Procesando ambiente: rd
# ✅ rd - Captura 1/600
# ✅ rd - Captura 2/600
# ✅ rd - Captura 3/600
# ✅ rd - Captura 4/600
# ✅ rd - Captura 5/600
# ✅ rd - Captura 6/600
# ✅ rd - Captura 7/600
# ✅ rd - Captura 8/600
# ✅ rd - Captura 9/600
# ✅ rd - Captura 10/600
# ✅ rd - Captura 11/600
# ✅ rd - Captura 12/600
# ✅ rd - Captura 13/600
# ✅ rd - Captura 14/600
# ✅ rd - Captura 15/600
# ✅ rd - Captura 16/600
# ✅ rd - Captura 17/600
# ✅ rd - Captura 18/600
# ✅ rd - Captura 19/600
# ✅ rd - Captura 20/600
# ✅ rd - Captura 21/600
# ✅ rd - Captura 22/600
# ✅ rd - Captura 23/600
# ✅ rd - Captura 24/600
# ✅ rd - Captura 25/600
# ✅ rd - Captura 26/600
# ✅ rd - Captura 27/600
# ✅ rd - Captura 28/600
# ✅ rd - Captura 29/600
# ✅ rd - Captura 30/600
# ✅ rd - Captura 31/600
# ✅ rd - Captura 32/600
# ✅ rd - Captura 33/600
# ✅ rd - Captura 34/600
# ✅ rd - Captura 35/600
# ✅ rd - Captura 36/600
# ✅ rd - Captura 37/600
# ✅ rd - Captura 38/600
# ✅ rd - Captura 39/600
# ✅ rd - Captura 40/600
# ✅ rd - Captura 41/600
# ✅ rd - Captura 42/600
# ✅ rd - Captura 43/600
# ✅ rd - Captura 44/600
# ✅ rd - Captura 45/600
# ✅ rd - Captura 46/600
# ✅ rd - Captura 47/600
# ✅ rd - Captura 48/600
# ✅ rd - Captura 49/600
# ✅ rd - Captura 50/600
# ✅ rd - Captura 51/600
# ✅ rd - Captura 52/600
# ✅ rd - Captura 53/600
# ✅ rd - Captura 54/600
# ✅ rd - Captura 55/600
# ✅ rd - Captura 56/600
# ✅ rd - Captura 57/600
# ✅ rd - Captura 58/600
# ✅ rd - Captura 59/600
# ✅ rd - Captura 60/600
# ✅ rd - Captura 61/600
# ✅ rd - Captura 62/600
# ✅ rd - Captura 63/600
# ✅ rd - Captura 64/600
# ✅ rd - Captura 65/600
# ✅ rd - Captura 66/600
# ✅ rd - Captura 67/600
# ✅ rd - Captura 68/600
# ✅ rd - Captura 69/600
# ✅ rd - Captura 70/600
# ✅ rd - Captura 71/600
# ✅ rd - Captura 72/600
# ✅ rd - Captura 73/600
# ✅ rd - Captura 74/600
# ✅ rd - Captura 75/600
# ✅ rd - Captura 76/600
# ✅ rd - Captura 77/600
# ✅ rd - Captura 78/600
# ✅ rd - Captura 79/600
# ✅ rd - Captura 80/600
# ✅ rd - Captura 81/600
# ✅ rd - Captura 82/600
# ✅ rd - Captura 83/600
# ✅ rd - Captura 84/600
# ✅ rd - Captura 85/600
# ✅ rd - Captura 86/600
# ✅ rd - Captura 87/600
# ✅ rd - Captura 88/600
# ✅ rd - Captura 89/600
# ✅ rd - Captura 90/600
# ✅ rd - Captura 91/600
# ✅ rd - Captura 92/600
# ✅ rd - Captura 93/600
# ✅ rd - Captura 94/600
# ✅ rd - Captura 95/600
# ✅ rd - Captura 96/600
# ✅ rd - Captura 97/600
# ✅ rd - Captura 98/600
# ✅ rd - Captura 99/600
# ✅ rd - Captura 100/600
# ✅ rd - Captura 101/600
# ✅ rd - Captura 102/600
# ✅ rd - Captura 103/600
# ✅ rd - Captura 104/600
# ✅ rd - Captura 105/600
# ✅ rd - Captura 106/600
# ✅ rd - Captura 107/600
# ✅ rd - Captura 108/600
# ✅ rd - Captura 109/600
# ✅ rd - Captura 110/600
# ✅ rd - Captura 111/600
# ✅ rd - Captura 112/600
# ✅ rd - Captura 113/600
# ✅ rd - Captura 114/600
# ✅ rd - Captura 115/600
# ✅ rd - Captura 116/600
# ✅ rd - Captura 117/600
# ✅ rd - Captura 118/600
# ✅ rd - Captura 119/600
# ✅ rd - Captura 120/600
# ✅ rd - Captura 121/600
# ✅ rd - Captura 122/600
# ✅ rd - Captura 123/600
# ✅ rd - Captura 124/600
# ✅ rd - Captura 125/600
# ✅ rd - Captura 126/600
# ✅ rd - Captura 127/600
# ✅ rd - Captura 128/600
# ✅ rd - Captura 129/600
# ✅ rd - Captura 130/600
# ✅ rd - Captura 131/600
# ✅ rd - Captura 132/600
# ✅ rd - Captura 133/600
# ✅ rd - Captura 134/600
# ✅ rd - Captura 135/600
# ✅ rd - Captura 136/600
# ✅ rd - Captura 137/600
# ✅ rd - Captura 138/600
# ✅ rd - Captura 139/600
# ✅ rd - Captura 140/600
# ✅ rd - Captura 141/600
# ✅ rd - Captura 142/600
# ✅ rd - Captura 143/600
# ✅ rd - Captura 144/600
# ✅ rd - Captura 145/600
# ✅ rd - Captura 146/600
# ✅ rd - Captura 147/600
# ✅ rd - Captura 148/600
# ✅ rd - Captura 149/600
# ✅ rd - Captura 150/600
# ✅ rd - Captura 151/600
# ✅ rd - Captura 152/600
# ✅ rd - Captura 153/600
# ✅ rd - Captura 154/600
# ✅ rd - Captura 155/600
# ✅ rd - Captura 156/600
# ✅ rd - Captura 157/600
# ✅ rd - Captura 158/600
# ✅ rd - Captura 159/600
# ✅ rd - Captura 160/600
# ✅ rd - Captura 161/600
# ✅ rd - Captura 162/600
# ✅ rd - Captura 163/600
# ✅ rd - Captura 164/600
# ✅ rd - Captura 165/600
# ✅ rd - Captura 166/600
# ✅ rd - Captura 167/600
# ✅ rd - Captura 168/600
# ✅ rd - Captura 169/600
# ✅ rd - Captura 170/600
# ✅ rd - Captura 171/600
# ✅ rd - Captura 172/600
# ✅ rd - Captura 173/600
# ✅ rd - Captura 174/600
# ✅ rd - Captura 175/600
# ✅ rd - Captura 176/600
# ✅ rd - Captura 177/600
# ✅ rd - Captura 178/600
# ✅ rd - Captura 179/600
# ✅ rd - Captura 180/600
# ✅ rd - Captura 181/600
# ✅ rd - Captura 182/600
# ✅ rd - Captura 183/600
# ✅ rd - Captura 184/600
# ✅ rd - Captura 185/600
# ✅ rd - Captura 186/600
# ✅ rd - Captura 187/600
# ✅ rd - Captura 188/600
# ✅ rd - Captura 189/600
# ✅ rd - Captura 190/600
# ✅ rd - Captura 191/600
# ✅ rd - Captura 192/600
# ✅ rd - Captura 193/600
# ✅ rd - Captura 194/600
# ✅ rd - Captura 195/600
# ✅ rd - Captura 196/600
# ✅ rd - Captura 197/600
# ✅ rd - Captura 198/600
# ✅ rd - Captura 199/600
# ✅ rd - Captura 200/600
# ✅ rd - Captura 201/600
# ✅ rd - Captura 202/600
# ✅ rd - Captura 203/600
# ✅ rd - Captura 204/600
# ✅ rd - Captura 205/600
# ✅ rd - Captura 206/600
# ✅ rd - Captura 207/600
# ✅ rd - Captura 208/600
# ✅ rd - Captura 209/600
# ✅ rd - Captura 210/600
# ✅ rd - Captura 211/600
# ✅ rd - Captura 212/600
# ✅ rd - Captura 213/600
# ✅ rd - Captura 214/600
# ✅ rd - Captura 215/600
# ✅ rd - Captura 216/600
# ✅ rd - Captura 217/600
# ✅ rd - Captura 218/600
# ✅ rd - Captura 219/600
# ✅ rd - Captura 220/600
# ✅ rd - Captura 221/600
# ✅ rd - Captura 222/600
# ✅ rd - Captura 223/600
# ✅ rd - Captura 224/600
# ✅ rd - Captura 225/600
# ✅ rd - Captura 226/600
# ✅ rd - Captura 227/600
# ✅ rd - Captura 228/600
# ✅ rd - Captura 229/600
# ✅ rd - Captura 230/600
# ✅ rd - Captura 231/600
# ✅ rd - Captura 232/600
# ✅ rd - Captura 233/600
# ✅ rd - Captura 234/600
# ✅ rd - Captura 235/600
# ✅ rd - Captura 236/600
# ✅ rd - Captura 237/600
# ✅ rd - Captura 238/600
# ✅ rd - Captura 239/600
# ✅ rd - Captura 240/600
# ✅ rd - Captura 241/600
# ✅ rd - Captura 242/600
# ✅ rd - Captura 243/600
# ✅ rd - Captura 244/600
# ✅ rd - Captura 245/600
# ✅ rd - Captura 246/600
# ✅ rd - Captura 247/600
# ✅ rd - Captura 248/600
# ✅ rd - Captura 249/600
# ✅ rd - Captura 250/600
# ✅ rd - Captura 251/600
# ✅ rd - Captura 252/600
# ✅ rd - Captura 253/600
# ✅ rd - Captura 254/600
# ✅ rd - Captura 255/600
# ✅ rd - Captura 256/600
# ✅ rd - Captura 257/600
# ✅ rd - Captura 258/600
# ✅ rd - Captura 259/600
# ✅ rd - Captura 260/600
# ✅ rd - Captura 261/600
# ✅ rd - Captura 262/600
# ✅ rd - Captura 263/600
# ✅ rd - Captura 264/600
# ✅ rd - Captura 265/600
# ✅ rd - Captura 266/600
# ✅ rd - Captura 267/600
# ✅ rd - Captura 268/600
# ✅ rd - Captura 269/600
# ✅ rd - Captura 270/600
# ✅ rd - Captura 271/600
# ✅ rd - Captura 272/600
# ✅ rd - Captura 273/600
# ✅ rd - Captura 274/600
# ✅ rd - Captura 275/600
# ✅ rd - Captura 276/600
# ✅ rd - Captura 277/600
# ✅ rd - Captura 278/600
# ✅ rd - Captura 279/600
# ✅ rd - Captura 280/600
# ✅ rd - Captura 281/600
# ✅ rd - Captura 282/600
# ✅ rd - Captura 283/600
# ✅ rd - Captura 284/600
# ✅ rd - Captura 285/600
# ✅ rd - Captura 286/600
# ✅ rd - Captura 287/600
# ✅ rd - Captura 288/600
# ✅ rd - Captura 289/600
# ✅ rd - Captura 290/600
# ✅ rd - Captura 291/600
# ✅ rd - Captura 292/600
# ✅ rd - Captura 293/600
# ✅ rd - Captura 294/600
# ✅ rd - Captura 295/600
# ✅ rd - Captura 296/600
# ✅ rd - Captura 297/600
# ✅ rd - Captura 298/600
# ✅ rd - Captura 299/600
# ✅ rd - Captura 300/600
# ✅ rd - Captura 301/600
# ✅ rd - Captura 302/600
# ✅ rd - Captura 303/600
# ✅ rd - Captura 304/600
# ✅ rd - Captura 305/600
# ✅ rd - Captura 306/600
# ✅ rd - Captura 307/600
# ✅ rd - Captura 308/600
# ✅ rd - Captura 309/600
# ✅ rd - Captura 310/600
# ✅ rd - Captura 311/600
# ✅ rd - Captura 312/600
# ✅ rd - Captura 313/600
# ✅ rd - Captura 314/600
# ✅ rd - Captura 315/600
# ✅ rd - Captura 316/600
# ✅ rd - Captura 317/600
# ✅ rd - Captura 318/600
# ✅ rd - Captura 319/600
# ✅ rd - Captura 320/600
# ✅ rd - Captura 321/600
# ✅ rd - Captura 322/600
# ✅ rd - Captura 323/600
# ✅ rd - Captura 324/600
# ✅ rd - Captura 325/600
# ✅ rd - Captura 326/600
# ✅ rd - Captura 327/600
# ✅ rd - Captura 328/600
# ✅ rd - Captura 329/600
# ✅ rd - Captura 330/600
# ✅ rd - Captura 331/600
# ✅ rd - Captura 332/600
# ✅ rd - Captura 333/600
# ✅ rd - Captura 334/600
# ✅ rd - Captura 335/600
# ✅ rd - Captura 336/600
# ✅ rd - Captura 337/600
# ✅ rd - Captura 338/600
# ✅ rd - Captura 339/600
# ✅ rd - Captura 340/600
# ✅ rd - Captura 341/600
# ✅ rd - Captura 342/600
# ✅ rd - Captura 343/600
# ✅ rd - Captura 344/600
# ✅ rd - Captura 345/600
# ✅ rd - Captura 346/600
# ✅ rd - Captura 347/600
# ✅ rd - Captura 348/600
# ✅ rd - Captura 349/600
# ✅ rd - Captura 350/600
# ✅ rd - Captura 351/600
# ✅ rd - Captura 352/600
# ✅ rd - Captura 353/600
# ✅ rd - Captura 354/600
# ✅ rd - Captura 355/600
# ✅ rd - Captura 356/600
# ✅ rd - Captura 357/600
# ✅ rd - Captura 358/600
# ✅ rd - Captura 359/600
# ✅ rd - Captura 360/600
# ✅ rd - Captura 361/600
# ✅ rd - Captura 362/600
# ✅ rd - Captura 363/600
# ✅ rd - Captura 364/600
# ✅ rd - Captura 365/600
# ✅ rd - Captura 366/600
# ✅ rd - Captura 367/600
# ✅ rd - Captura 368/600
# ✅ rd - Captura 369/600
# ✅ rd - Captura 370/600
# ✅ rd - Captura 371/600
# ✅ rd - Captura 372/600
# ✅ rd - Captura 373/600
# ✅ rd - Captura 374/600
# ✅ rd - Captura 375/600
# ✅ rd - Captura 376/600
# ✅ rd - Captura 377/600
# ✅ rd - Captura 378/600
# ✅ rd - Captura 379/600
# ✅ rd - Captura 380/600
# ✅ rd - Captura 381/600
# ✅ rd - Captura 382/600
# ✅ rd - Captura 383/600
# ✅ rd - Captura 384/600
# ✅ rd - Captura 385/600
# ✅ rd - Captura 386/600
# ✅ rd - Captura 387/600
# ✅ rd - Captura 388/600
# ✅ rd - Captura 389/600
# ✅ rd - Captura 390/600
# ✅ rd - Captura 391/600
# ✅ rd - Captura 392/600
# ✅ rd - Captura 393/600
# ✅ rd - Captura 394/600
# ✅ rd - Captura 395/600
# ✅ rd - Captura 396/600
# ✅ rd - Captura 397/600
# ✅ rd - Captura 398/600
# ✅ rd - Captura 399/600
# ✅ rd - Captura 400/600
# ✅ rd - Captura 401/600
# ✅ rd - Captura 402/600
# ✅ rd - Captura 403/600
# ✅ rd - Captura 404/600
# ✅ rd - Captura 405/600
# ✅ rd - Captura 406/600
# ✅ rd - Captura 407/600
# ✅ rd - Captura 408/600
# ✅ rd - Captura 409/600
# ✅ rd - Captura 410/600
# ✅ rd - Captura 411/600
# ✅ rd - Captura 412/600
# ✅ rd - Captura 413/600
# ✅ rd - Captura 414/600
# ✅ rd - Captura 415/600
# ✅ rd - Captura 416/600
# ✅ rd - Captura 417/600
# ✅ rd - Captura 418/600
# ✅ rd - Captura 419/600
# ✅ rd - Captura 420/600
# ✅ rd - Captura 421/600
# ✅ rd - Captura 422/600
# ✅ rd - Captura 423/600
# ✅ rd - Captura 424/600
# ✅ rd - Captura 425/600
# ✅ rd - Captura 426/600
# ✅ rd - Captura 427/600
# ✅ rd - Captura 428/600
# ✅ rd - Captura 429/600
# ✅ rd - Captura 430/600
# ✅ rd - Captura 431/600
# ✅ rd - Captura 432/600
# ✅ rd - Captura 433/600
# ✅ rd - Captura 434/600
# ✅ rd - Captura 435/600
# ✅ rd - Captura 436/600
# ✅ rd - Captura 437/600
# ✅ rd - Captura 438/600
# ✅ rd - Captura 439/600
# ✅ rd - Captura 440/600
# ✅ rd - Captura 441/600
# ✅ rd - Captura 442/600
# ✅ rd - Captura 443/600
# ✅ rd - Captura 444/600
# ✅ rd - Captura 445/600
# ✅ rd - Captura 446/600
# ✅ rd - Captura 447/600
# ✅ rd - Captura 448/600
# ✅ rd - Captura 449/600
# ✅ rd - Captura 450/600
# ✅ rd - Captura 451/600
# ✅ rd - Captura 452/600
# ✅ rd - Captura 453/600
# ✅ rd - Captura 454/600
# ✅ rd - Captura 455/600
# ✅ rd - Captura 456/600
# ✅ rd - Captura 457/600
# ✅ rd - Captura 458/600
# ✅ rd - Captura 459/600
# ✅ rd - Captura 460/600
# ✅ rd - Captura 461/600
# ✅ rd - Captura 462/600
# ✅ rd - Captura 463/600
# ✅ rd - Captura 464/600
# ✅ rd - Captura 465/600
# ✅ rd - Captura 466/600
# ✅ rd - Captura 467/600
# ✅ rd - Captura 468/600
# ✅ rd - Captura 469/600
# ✅ rd - Captura 470/600
# ✅ rd - Captura 471/600
# ✅ rd - Captura 472/600
# ✅ rd - Captura 473/600
# ✅ rd - Captura 474/600
# ✅ rd - Captura 475/600
# ✅ rd - Captura 476/600
# ✅ rd - Captura 477/600
# ✅ rd - Captura 478/600
# ✅ rd - Captura 479/600
# ✅ rd - Captura 480/600
# ✅ rd - Captura 481/600
# ✅ rd - Captura 482/600
# ✅ rd - Captura 483/600
# ✅ rd - Captura 484/600
# ✅ rd - Captura 485/600
# ✅ rd - Captura 486/600
# ✅ rd - Captura 487/600
# ✅ rd - Captura 488/600
# ✅ rd - Captura 489/600
# ✅ rd - Captura 490/600
# ✅ rd - Captura 491/600
# ✅ rd - Captura 492/600
# ✅ rd - Captura 493/600
# ✅ rd - Captura 494/600
# ✅ rd - Captura 495/600
# ✅ rd - Captura 496/600
# ✅ rd - Captura 497/600
# ✅ rd - Captura 498/600
# ✅ rd - Captura 499/600
# ✅ rd - Captura 500/600
# ✅ rd - Captura 501/600
# ✅ rd - Captura 502/600
# ✅ rd - Captura 503/600
# ✅ rd - Captura 504/600
# ✅ rd - Captura 505/600
# ✅ rd - Captura 506/600
# ✅ rd - Captura 507/600
# ✅ rd - Captura 508/600
# ✅ rd - Captura 509/600
# ✅ rd - Captura 510/600
# ✅ rd - Captura 511/600
# ✅ rd - Captura 512/600
# ✅ rd - Captura 513/600
# ✅ rd - Captura 514/600
# ✅ rd - Captura 515/600
# ✅ rd - Captura 516/600
# ✅ rd - Captura 517/600
# ✅ rd - Captura 518/600
# ✅ rd - Captura 519/600
# ✅ rd - Captura 520/600
# ✅ rd - Captura 521/600
# ✅ rd - Captura 522/600
# ✅ rd - Captura 523/600
# ✅ rd - Captura 524/600
# ✅ rd - Captura 525/600
# ✅ rd - Captura 526/600
# ✅ rd - Captura 527/600
# ✅ rd - Captura 528/600
# ✅ rd - Captura 529/600
# ✅ rd - Captura 530/600
# ✅ rd - Captura 531/600
# ✅ rd - Captura 532/600
# ✅ rd - Captura 533/600
# ✅ rd - Captura 534/600
# ✅ rd - Captura 535/600
# ✅ rd - Captura 536/600
# ✅ rd - Captura 537/600
# ✅ rd - Captura 538/600
# ✅ rd - Captura 539/600
# ✅ rd - Captura 540/600
# ✅ rd - Captura 541/600
# ✅ rd - Captura 542/600
# ✅ rd - Captura 543/600
# ✅ rd - Captura 544/600
# ✅ rd - Captura 545/600
# ✅ rd - Captura 546/600
# ✅ rd - Captura 547/600
# ✅ rd - Captura 548/600
# ✅ rd - Captura 549/600
# ✅ rd - Captura 550/600
# ✅ rd - Captura 551/600
# ✅ rd - Captura 552/600
# ✅ rd - Captura 553/600
# ✅ rd - Captura 554/600
# ✅ rd - Captura 555/600
# ✅ rd - Captura 556/600
# ✅ rd - Captura 557/600
# ✅ rd - Captura 558/600
# ✅ rd - Captura 559/600
# ✅ rd - Captura 560/600
# ✅ rd - Captura 561/600
# ✅ rd - Captura 562/600
# ✅ rd - Captura 563/600
# ✅ ud - Captura 36/600
# ✅ ud - Captura 37/600
# ✅ ud - Captura 38/600
# ✅ ud - Captura 39/600
# ✅ ud - Captura 40/600
# ✅ ud - Captura 41/600
# ✅ ud - Captura 42/600
# ✅ ud - Captura 43/600
# ...
# ✅ uj - Captura 526/600
# ✅ uj - Captura 527/600
# ✅ uj - Captura 528/600
# ✅ uj - Captura 529/600
# ✅ uj - Captura 530/600
# ✅ uj - Captura 531/600
# ✅ uj - Captura 532/600
# ✅ uj - Captura 533/600
# ✅ uj - Captura 534/600
# ✅ uj - Captura 535/600
# ✅ uj - Captura 536/600
# ✅ uj - Captura 537/600
# ✅ uj - Captura 538/600
# ✅ uj - Captura 539/600
# ✅ uj - Captura 540/600
# ✅ uj - Captura 541/600
# ✅ uj - Captura 542/600
# ✅ uj - Captura 543/600
# ✅ uj - Captura 544/600
# ✅ uj - Captura 545/600
# ✅ uj - Captura 546/600
# ✅ uj - Captura 547/600
# ✅ uj - Captura 548/600
# ✅ uj - Captura 549/600
# ✅ uj - Captura 550/600
# ✅ uj - Captura 551/600
# ✅ uj - Captura 552/600
# ✅ uj - Captura 553/600
# ✅ uj - Captura 554/600
# ✅ uj - Captura 555/600
# ✅ uj - Captura 556/600
# ✅ uj - Captura 557/600
# ✅ uj - Captura 558/600
# ✅ uj - Captura 559/600
# ✅ uj - Captura 560/600
# ✅ uj - Captura 561/600
# ✅ uj - Captura 562/600
# ✅ uj - Captura 563/600
# ✅ uj - Captura 564/600
# ✅ uj - Captura 565/600
# ✅ uj - Captura 566/600
# ✅ uj - Captura 567/600
# ✅ uj - Captura 568/600
# ✅ uj - Captura 569/600
# ✅ uj - Captura 570/600
# ✅ uj - Captura 571/600
# ✅ uj - Captura 572/600
# ✅ uj - Captura 573/600
# ✅ uj - Captura 574/600
# ✅ uj - Captura 575/600
# ✅ uj - Captura 576/600
# ✅ uj - Captura 577/600
# ✅ uj - Captura 578/600
# ✅ uj - Captura 579/600
# ✅ uj - Captura 580/600
# ✅ uj - Captura 581/600
# ✅ uj - Captura 582/600
# ✅ uj - Captura 583/600
# ✅ uj - Captura 584/600
# ✅ uj - Captura 585/600
# ✅ uj - Captura 586/600
# ✅ uj - Captura 587/600
# ✅ uj - Captura 588/600
# ✅ uj - Captura 589/600
# ✅ uj - Captura 590/600
# ✅ uj - Captura 591/600
# ✅ uj - Captura 592/600
# ✅ uj - Captura 593/600
# ✅ uj - Captura 594/600
# ✅ uj - Captura 595/600
# ✅ uj - Captura 596/600
# ✅ uj - Captura 597/600
# ✅ uj - Captura 598/600
# ✅ uj - Captura 599/600
# ✅ uj - Captura 600/600
# 🎉 Clase 'uj' completada con 600 capturas únicas.
#
# 🌴 Procesando ambiente: vi
# ✅ vi - Captura 1/600
# ✅ vi - Captura 2/600
# ✅ vi - Captura 3/600
# ✅ vi - Captura 4/600
# ✅ vi - Captura 5/600
# ✅ vi - Captura 6/600
# ✅ vi - Captura 7/600
# ✅ vi - Captura 8/600
# ✅ vi - Captura 9/600
# ✅ vi - Captura 10/600
# ✅ vi - Captura 11/600
# ✅ vi - Captura 496/600
# ✅ vi - Captura 497/600
# ✅ vi - Captura 498/600
# ✅ vi - Captura 499/600
# ✅ vi - Captura 500/600
# ✅ vi - Captura 501/600
# ✅ vi - Captura 502/600
# ✅ vi - Captura 503/600
# ✅ vi - Captura 504/600
# ✅ vi - Captura 505/600
# ✅ vi - Captura 506/600
# ✅ vi - Captura 507/600
# ✅ vi - Captura 508/600
# ✅ vi - Captura 509/600
# ✅ vi - Captura 510/600
# ✅ vi - Captura 511/600
# ✅ vi - Captura 512/600
# ✅ vi - Captura 513/600
# ✅ vi - Captura 514/600
# ✅ vi - Captura 515/600
# ✅ vi - Captura 516/600
# ✅ vi - Captura 517/600
# ✅ vi - Captura 518/600
# ✅ vi - Captura 519/600
# ✅ vi - Captura 520/600
# ✅ vi - Captura 521/600
# ✅ vi - Captura 522/600
# ✅ vi - Captura 523/600
# ✅ vi - Captura 524/600
# ✅ vi - Captura 525/600
# ✅ vi - Captura 526/600
# ✅ vi - Captura 527/600
# ✅ vi - Captura 528/600
# ✅ vi - Captura 529/600
# ✅ vi - Captura 530/600
# ✅ vi - Captura 531/600
# ✅ vi - Captura 532/600
# ✅ vi - Captura 533/600
# ✅ vi - Captura 534/600
# ✅ vi - Captura 535/600
# ✅ vi - Captura 536/600
# ✅ vi - Captura 537/600
# ✅ vi - Captura 538/600
# ✅ vi - Captura 539/600
# ✅ vi - Captura 540/600
# ✅ vi - Captura 541/600
# ✅ vi - Captura 542/600
# ✅ vi - Captura 543/600
# ✅ vi - Captura 544/600
# ✅ vi - Captura 545/600
# ✅ vi - Captura 546/600
# ✅ vi - Captura 547/600
# ✅ vi - Captura 548/600
# ✅ vi - Captura 549/600
# ✅ vi - Captura 550/600
# ✅ vi - Captura 551/600
# ✅ vi - Captura 552/600
# ✅ vi - Captura 553/600
# ✅ vi - Captura 554/600
# ✅ vi - Captura 555/600
# ✅ vi - Captura 556/600
# ✅ vi - Captura 557/600
# ✅ vi - Captura 558/600
# ✅ vi - Captura 559/600
# ✅ vi - Captura 560/600
# ✅ vi - Captura 561/600
# ✅ vi - Captura 562/600
# ✅ vi - Captura 563/600
# ✅ vi - Captura 564/600
# ✅ vi - Captura 565/600
# ✅ vi - Captura 566/600
# ✅ vi - Captura 567/600
# ✅ vi - Captura 568/600
# ✅ vi - Captura 569/600
# ✅ vi - Captura 570/600
# ✅ vi - Captura 571/600
# ✅ vi - Captura 572/600
# ✅ vi - Captura 573/600
# ✅ vi - Captura 574/600
# ✅ vi - Captura 575/600
# ✅ vi - Captura 576/600
# ✅ vi - Captura 577/600
# ✅ vi - Captura 578/600
# ✅ vi - Captura 579/600
# ✅ vi - Captura 580/600
# ✅ vi - Captura 581/600
# ✅ vi - Captura 582/600
# ✅ vi - Captura 583/600
# ✅ vi - Captura 584/600
# ✅ vi - Captura 585/600
# ✅ vi - Captura 586/600
# ✅ vi - Captura 587/600
# ✅ vi - Captura 588/600
# ✅ vi - Captura 589/600
# ✅ vi - Captura 590/600
# ✅ vi - Captura 591/600
# ✅ vi - Captura 592/600
# ✅ vi - Captura 593/600
# ✅ vi - Captura 594/600
# ✅ vi - Captura 595/600
# ✅ vi - Captura 596/600
# ✅ vi - Captura 597/600
# ✅ vi - Captura 598/600
# ✅ vi - Captura 599/600
# ✅ vi - Captura 600/600
# 🎉 Clase 'vi' completada con 600 capturas únicas.
#
# 📦 Dividiendo capturas en Train / Val / Test...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 127
#     125 images = [f for f in os.listdir(ambiente_src) if f.endswith(".png")]
#     126 images.sort()
# --> 127 random.seed(42)
#     128 random.shuffle(images)
#     130 n_total = len(images)
#
# NameError: name 'random' is not defined

# %% [markdown]
# Creates Train/Val/Test folders and splits the images into them.

# %%
output_folder = r"F:\Universidad\Curso 2024-25\Segundo Semestre\TFG\Desarrollo\dataset\classification_per_type\environment_classification_dataset"
os.makedirs(output_folder, exist_ok=True)

capture_folder = os.path.join(output_folder, "CapturesRaw")
os.makedirs(capture_folder, exist_ok=True)

folders = {
    "train": os.path.join(output_folder, "Train"),
    "val": os.path.join(output_folder, "Val"),
    "test": os.path.join(output_folder, "Test")
}

islands = ["GRAN CANARIA", "TENERIFE", "LA GOMERA"]

data_islands = data[data["ISLA"].isin(islands)].copy()
data_env = data_islands[data_islands["Tip_amb"].notna()].copy()

# Rellenar los nulos con "pc"
data_islands["Hibrid"] = data_islands["Hibrid"].fillna("pc")
data_type = data_islands.copy()

# Crear diccionarios de clases
env_classes = {k: i for i, k in enumerate(sorted(data_env["Tip_amb"].unique())) if k != "?"}
type_classes = {k: i for i, k in enumerate(sorted(data_type["Hibrid"].unique())) if k != "?"}

for ambiente in env_classes.keys():
    ambiente_src = os.path.join(capture_folder, ambiente)
    if not os.path.exists(ambiente_src):
        continue

    images = [f for f in os.listdir(ambiente_src) if f.endswith(".png")]
    images.sort()
    random.seed(42)
    random.shuffle(images)

    n_total = len(images)
    n_train = int(n_total * 0.7)
    n_val = int(n_total * 0.2)
    n_test = n_total - n_train - n_val

    split_counts = {"Train": n_train, "Val": n_val, "Test": n_test}
    split_images = {
        "Train": images[:n_train],
        "Val": images[n_train:n_train + n_val],
        "Test": images[n_train + n_val:]
    }

    for split_name in ["Train", "Val", "Test"]:
        out_dir = os.path.join(output_folder, split_name, ambiente)
        os.makedirs(out_dir, exist_ok=True)

        for img in split_images[split_name]:
            src = os.path.join(ambiente_src, img)
            dst = os.path.join(out_dir, img)
            shutil.copy2(src, dst)  # ← Copia en lugar de mover

        print(f"{split_name}/{ambiente}: {split_counts[split_name]} imágenes")

print("\nDataset preparado copiando en estructura Train / Val / Test.")
# Out:
# Train/na: 420 imágenes
# Val/na: 120 imágenes
# Test/na: 60 imágenes
# Train/ot: 369 imágenes
# Val/ot: 105 imágenes
# Test/ot: 54 imágenes
# Train/rd: 420 imágenes
# Val/rd: 120 imágenes
# Test/rd: 60 imágenes
# Train/ru: 420 imágenes
# Val/ru: 120 imágenes
# Test/ru: 60 imágenes
# Train/ud: 420 imágenes
# Val/ud: 120 imágenes
# Test/ud: 60 imágenes
# Train/uj: 420 imágenes
# Val/uj: 120 imágenes
# Test/uj: 60 imágenes
# Train/vi: 420 imágenes
# Val/vi: 120 imágenes
# Test/vi: 60 imágenes
#
# Dataset preparado copiando en estructura Train / Val / Test.

# %% [markdown]
# Move folder Train/Val/Test to root folder (all images together)

# %%
output_folder = r"F:\Universidad\Curso 2024-25\Segundo Semestre\TFG\Desarrollo\dataset\classification_per_type\environment_classification_dataset"
capture_folder = os.path.join(output_folder, "CapturesRaw")

for split in ["Train", "Val", "Test"]:
    split_dir = os.path.join(output_folder, split)
    if not os.path.exists(split_dir):
        continue

    for ambiente in os.listdir(split_dir):
        ambiente_dir = os.path.join(split_dir, ambiente)
        if not os.path.isdir(ambiente_dir):
            continue

        dest_folder = os.path.join(capture_folder, ambiente)
        os.makedirs(dest_folder, exist_ok=True)

        for file in os.listdir(ambiente_dir):
            if file.endswith(".png"):
                src = os.path.join(ambiente_dir, file)
                dst = os.path.join(dest_folder, file)
                shutil.move(src, dst)

        print(f"{split}/{ambiente} → CapturesRaw/{ambiente}")

print("\nTodas las imágenes han sido devueltas a sus carpetas originales.")
# Out:
# Todas las imágenes han sido devueltas a sus carpetas originales.

# %% [markdown]
# only for fulfilling ot env class

# %%
# --- Configuración ---
output_folder = r"F:\Universidad\Curso 2024-25\Segundo Semestre\TFG\Desarrollo\dataset\classification_per_type\environment_classification_dataset"
capture_folder = os.path.join(output_folder, "CapturesRaw")
os.makedirs(capture_folder, exist_ok=True)

ambiente = "ot"
max_per_class = 600
img_size = 256
scale = 1000

# --- Cargar datos ---
islands = ["GRAN CANARIA", "TENERIFE", "LA GOMERA"]
data_islands = data[data["ISLA"].isin(islands)].copy()
data_islands["Hibrid"] = data_islands["Hibrid"].fillna("pc")
data_env = data_islands[(data_islands["Tip_amb"] == ambiente)].copy()
data_env = data_env.to_crs(epsg=32628)

# --- ArcGIS setup ---
project = arcpy.mp.ArcGISProject("CURRENT")
map_view = project.activeView
camera = map_view.camera
camera.spatialReference = arcpy.SpatialReference(32628)
map_view.camera = camera

def get_extent(row):
    camera.X = row.geometry.x
    camera.Y = row.geometry.y
    camera.scale = scale
    map_view.camera = camera
    time.sleep(0.25)
    return map_view.camera.getExtent()

# --- Preparar carpetas ---
ambiente_folder = os.path.join(capture_folder, ambiente)
os.makedirs(ambiente_folder, exist_ok=True)

worldfile_folder = os.path.join(ambiente_folder, "worldfiles")
os.makedirs(worldfile_folder, exist_ok=True)

# --- Iniciar captura ---
print(f"\nProcesando ambiente: {ambiente}")
clase_df = data_env.copy()
clase_df = clase_df.sample(frac=1, random_state=42).reset_index()

used_extents = []
processed_ids = set()
saved = 0

# --- Primera pasada: solo palmeras fuera de extents ---
while saved < max_per_class:
    new_captures = 0

    for idx, row in clase_df.iterrows():
        if row["index"] in processed_ids:
            continue

        extent = get_extent(row)
        capture_box = shapely.geometry.box(extent.XMin, extent.YMin, extent.XMax, extent.YMax)

        if any(capture_box.intersects(prev) for prev in used_extents):
            continue

        image_name = f"{ambiente}_{row['index']}.png"
        image_path = os.path.join(ambiente_folder, image_name)
        map_view.exportToPNG(image_path, img_size, img_size, world_file=True)

        pgw_src = image_path.replace(".png", ".pgw")
        pgw_dst = os.path.join(worldfile_folder, os.path.basename(pgw_src))
        if os.path.exists(pgw_src):
            shutil.move(pgw_src, pgw_dst)
        else:
            print(f"⚠️ Worldfile no encontrado para: {image_name}")

        used_extents.append(capture_box)
        processed_ids.add(row["index"])
        saved += 1
        new_captures += 1
        print(f"{ambiente} - Captura única {saved}/{max_per_class}")

        if saved >= max_per_class:
            break

    if new_captures == 0:
        print(f"No se alcanzaron {max_per_class} capturas únicas. Se completará con imágenes solapadas.")
        break

# --- Segunda pasada: permitir solapamiento para completar ---
if saved < max_per_class:
    for idx, row in clase_df.iterrows():
        if row["index"] in processed_ids:
            continue

        extent = get_extent(row)
        image_name = f"{ambiente}_{row['index']}.png"
        image_path = os.path.join(ambiente_folder, image_name)
        map_view.exportToPNG(image_path, img_size, img_size, world_file=True)

        pgw_src = image_path.replace(".png", ".pgw")
        pgw_dst = os.path.join(worldfile_folder, os.path.basename(pgw_src))
        if os.path.exists(pgw_src):
            shutil.move(pgw_src, pgw_dst)

        processed_ids.add(row["index"])
        saved += 1
        print(f"{ambiente} - Captura solapada {saved}/{max_per_class}")

        if saved >= max_per_class:
            print(f"'{ambiente}' completado con imágenes solapadas.")
            break

print(f"\n🎉 Captura finalizada para '{ambiente}' con {saved} imágenes.")
# Out:
# Procesando ambiente: ot
# ot - Captura única 1/600
# ot - Captura única 2/600
# ot - Captura única 3/600
# ot - Captura única 4/600
# ot - Captura única 5/600
# ot - Captura única 6/600
# ot - Captura única 7/600
# ot - Captura única 8/600
# ot - Captura única 9/600
# ot - Captura única 10/600
# ot - Captura única 11/600
# ot - Captura única 12/600
# ot - Captura única 13/600
# ot - Captura única 14/600
# ot - Captura única 15/600
# ot - Captura única 16/600
# ot - Captura única 17/600
# ot - Captura única 18/600
# ot - Captura única 19/600
# ot - Captura única 20/600
# ot - Captura única 21/600
# ot - Captura única 22/600
# ot - Captura única 23/600
# ot - Captura única 24/600
# ot - Captura única 25/600
# ot - Captura única 26/600
# ot - Captura única 27/600
# ot - Captura única 28/600
# ot - Captura única 29/600
# ot - Captura única 30/600
# ot - Captura única 31/600
# ot - Captura única 32/600
# ot - Captura única 33/600
# ot - Captura única 34/600
# ot - Captura única 35/600
# ot - Captura única 36/600
# ot - Captura única 37/600
# ot - Captura única 38/600
# ot - Captura única 39/600
# ot - Captura única 40/600
# ot - Captura única 41/600
# ot - Captura única 42/600
# ot - Captura única 43/600
# ot - Captura única 44/600
# ot - Captura única 45/600
# ot - Captura única 46/600
# ot - Captura única 47/600
# ot - Captura única 48/600
# ot - Captura única 49/600
# ot - Captura única 50/600
# ot - Captura única 51/600
# ot - Captura única 52/600
# ot - Captura única 53/600
# ot - Captura única 54/600
# ot - Captura única 55/600
# ot - Captura única 56/600
# ot - Captura única 57/600
# ot - Captura única 58/600
# ot - Captura única 59/600
# ot - Captura única 60/600
# ot - Captura única 61/600
# ot - Captura única 62/600
# ot - Captura única 63/600
# ot - Captura única 64/600
# ot - Captura única 65/600
# ot - Captura única 66/600
# ot - Captura única 67/600
# ot - Captura única 68/600
# ot - Captura única 69/600
# ot - Captura única 70/600
# ot - Captura única 71/600
# ot - Captura única 72/600
# ot - Captura única 73/600
# ot - Captura única 74/600
# ot - Captura única 75/600
# ot - Captura única 76/600
# ot - Captura única 77/600
# ot - Captura única 78/600
# ot - Captura única 79/600
# ot - Captura única 80/600
# ot - Captura única 81/600
# ot - Captura única 82/600
# ot - Captura única 83/600
# ot - Captura única 84/600
# ot - Captura única 85/600
# ot - Captura única 86/600
# ot - Captura única 87/600
# ot - Captura única 88/600
# ot - Captura única 89/600
# ot - Captura única 90/600
# ot - Captura única 91/600
# ot - Captura única 92/600
# ot - Captura única 93/600
# ot - Captura única 94/600
# ot - Captura única 95/600
# ot - Captura única 96/600
# ot - Captura única 97/600
# ot - Captura única 98/600
# ot - Captura única 99/600
# ot - Captura única 100/600
# ot - Captura única 101/600
# ot - Captura única 102/600
# ot - Captura única 103/600
# ot - Captura única 104/600
# ot - Captura única 105/600
# ot - Captura única 106/600
# ot - Captura única 107/600
# ot - Captura única 108/600
# ot - Captura única 109/600
# ot - Captura única 110/600
# ot - Captura única 111/600
# ot - Captura única 112/600
# ot - Captura única 113/600
# ot - Captura única 114/600
# ot - Captura única 115/600
# ot - Captura única 116/600
# ot - Captura única 117/600
# ot - Captura única 118/600
# ot - Captura única 119/600
# ot - Captura única 120/600
# ot - Captura única 121/600
# ot - Captura única 122/600
# ot - Captura única 123/600
# ot - Captura única 124/600
# ot - Captura única 125/600
# ot - Captura única 126/600
# ot - Captura única 127/600
# ot - Captura única 128/600
# ot - Captura única 129/600
# ot - Captura única 130/600
# ot - Captura única 131/600
# ot - Captura única 132/600
# ot - Captura única 133/600
# ot - Captura única 134/600
# ot - Captura única 135/600
# ot - Captura única 136/600
# ot - Captura única 137/600
# ot - Captura única 138/600
# ot - Captura única 139/600
# ot - Captura única 140/600
# ot - Captura única 141/600
# ot - Captura única 142/600
# ot - Captura única 143/600
# ot - Captura única 144/600
# ot - Captura única 145/600
# ot - Captura única 146/600
# ot - Captura única 147/600
# ot - Captura única 148/600
# ot - Captura única 149/600
# ot - Captura única 150/600
# ot - Captura única 151/600
# ot - Captura única 152/600
# ot - Captura única 153/600
# ot - Captura única 154/600
# ot - Captura única 155/600
# ot - Captura única 156/600
# ot - Captura única 157/600
# ot - Captura única 158/600
# ot - Captura única 159/600
# ot - Captura única 160/600
# ot - Captura única 161/600
# ot - Captura única 162/600
# ot - Captura única 163/600
# ot - Captura única 164/600
# ot - Captura única 165/600
# ot - Captura única 166/600
# ot - Captura única 167/600
# ot - Captura única 168/600
# ot - Captura única 169/600
# ot - Captura única 170/600
# ot - Captura única 171/600
# ot - Captura única 172/600
# ot - Captura única 173/600
# ot - Captura única 174/600
# ot - Captura única 175/600
# ot - Captura única 176/600
# ot - Captura única 177/600
# ot - Captura única 178/600
# ot - Captura única 179/600
# ot - Captura única 180/600
# ot - Captura única 181/600
# ot - Captura única 182/600
# ot - Captura única 183/600
# ot - Captura única 184/600
# ot - Captura única 185/600
# ot - Captura única 186/600
# ot - Captura única 187/600
# ot - Captura única 188/600
# ot - Captura única 189/600
# ot - Captura única 190/600
# ot - Captura única 191/600
# ot - Captura única 192/600
# ot - Captura única 193/600
# ot - Captura única 194/600
# ot - Captura única 195/600
# ot - Captura única 196/600
# ot - Captura única 197/600
# ot - Captura única 198/600
# ot - Captura única 199/600
# ot - Captura única 200/600
# ot - Captura única 201/600
# ot - Captura única 202/600
# ot - Captura única 203/600
# ot - Captura única 204/600
# ot - Captura única 205/600
# ot - Captura única 206/600
# ot - Captura única 207/600
# ot - Captura única 208/600
# ot - Captura única 209/600
# ot - Captura única 210/600
# ot - Captura única 211/600
# ot - Captura única 212/600
# ot - Captura única 213/600
# ot - Captura única 214/600
# ot - Captura única 215/600
# ot - Captura única 216/600
# ot - Captura única 217/600
# ot - Captura única 218/600
# ot - Captura única 219/600
# ot - Captura única 220/600
# ot - Captura única 221/600
# ot - Captura única 222/600
# ot - Captura única 223/600
# ot - Captura única 224/600
# ot - Captura única 225/600
# ot - Captura única 226/600
# ot - Captura única 227/600
# ot - Captura única 228/600
# ot - Captura única 229/600
# ot - Captura única 230/600
# ot - Captura única 231/600
# ot - Captura única 232/600
# ot - Captura única 233/600
# ot - Captura única 234/600
# ot - Captura única 235/600
# ot - Captura única 236/600
# No se alcanzaron 600 capturas únicas. Se completará con imágenes solapadas.
# ot - Captura solapada 237/600
# ot - Captura solapada 238/600
# ot - Captura solapada 239/600
# ot - Captura solapada 240/600
# ot - Captura solapada 241/600
# ot - Captura solapada 242/600
# ot - Captura solapada 243/600
# ot - Captura solapada 244/600
# ot - Captura solapada 245/600
# ot - Captura solapada 246/600
# ot - Captura solapada 247/600
# ot - Captura solapada 248/600
# ot - Captura solapada 249/600
# ot - Captura solapada 250/600
# ot - Captura solapada 251/600
# ot - Captura solapada 252/600
# ot - Captura solapada 253/600
# ot - Captura solapada 254/600
# ot - Captura solapada 255/600
# ot - Captura solapada 256/600
# ot - Captura solapada 257/600
# ot - Captura solapada 258/600
# ot - Captura solapada 259/600
# ot - Captura solapada 260/600
# ot - Captura solapada 261/600
# ot - Captura solapada 262/600
# ot - Captura solapada 263/600
# ot - Captura solapada 264/600
# ot - Captura solapada 265/600
# ot - Captura solapada 266/600
# ot - Captura solapada 267/600
# ot - Captura solapada 268/600
# ot - Captura solapada 269/600
# ot - Captura solapada 270/600
# ot - Captura solapada 271/600
# ot - Captura solapada 272/600
# ot - Captura solapada 273/600
# ot - Captura solapada 274/600
# ot - Captura solapada 275/600
# ot - Captura solapada 276/600
# ot - Captura solapada 277/600
# ot - Captura solapada 278/600
# ot - Captura solapada 279/600
# ot - Captura solapada 280/600
# ot - Captura solapada 281/600
# ot - Captura solapada 282/600
# ot - Captura solapada 283/600
# ot - Captura solapada 284/600
# ot - Captura solapada 285/600
# ot - Captura solapada 286/600
# ot - Captura solapada 287/600
# ot - Captura solapada 288/600
# ot - Captura solapada 289/600
# ot - Captura solapada 290/600
# ot - Captura solapada 291/600
# ot - Captura solapada 292/600
# ot - Captura solapada 293/600
# ot - Captura solapada 294/600
# ot - Captura solapada 295/600
# ot - Captura solapada 296/600
# ot - Captura solapada 297/600
# ot - Captura solapada 298/600
# ot - Captura solapada 299/600
# ot - Captura solapada 300/600
# ot - Captura solapada 301/600
# ot - Captura solapada 302/600
# ot - Captura solapada 303/600
# ot - Captura solapada 304/600
# ot - Captura solapada 305/600
# ot - Captura solapada 306/600
# ot - Captura solapada 307/600
# ot - Captura solapada 308/600
# ot - Captura solapada 309/600
# ot - Captura solapada 310/600
# ot - Captura solapada 311/600
# ot - Captura solapada 312/600
# ot - Captura solapada 313/600
# ot - Captura solapada 314/600
# ot - Captura solapada 315/600
# ot - Captura solapada 316/600
# ot - Captura solapada 317/600
# ot - Captura solapada 318/600
# ot - Captura solapada 319/600
# ot - Captura solapada 320/600
# ot - Captura solapada 321/600
# ot - Captura solapada 322/600
# ot - Captura solapada 323/600
# ot - Captura solapada 324/600
# ot - Captura solapada 325/600
# ot - Captura solapada 326/600
# ot - Captura solapada 327/600
# ot - Captura solapada 328/600
# ot - Captura solapada 329/600
# ot - Captura solapada 330/600
# ot - Captura solapada 331/600
# ot - Captura solapada 332/600
# ot - Captura solapada 333/600
# ot - Captura solapada 334/600
# ot - Captura solapada 335/600
# ot - Captura solapada 336/600
# ot - Captura solapada 337/600
# ot - Captura solapada 338/600
# ot - Captura solapada 339/600
# ot - Captura solapada 340/600
# ot - Captura solapada 341/600
# ot - Captura solapada 342/600
# ot - Captura solapada 343/600
# ot - Captura solapada 344/600
# ot - Captura solapada 345/600
# ot - Captura solapada 346/600
# ot - Captura solapada 347/600
# ot - Captura solapada 348/600
# ot - Captura solapada 349/600
# ot - Captura solapada 350/600
# ot - Captura solapada 351/600
# ot - Captura solapada 352/600
# ot - Captura solapada 353/600
# ot - Captura solapada 354/600
# ot - Captura solapada 355/600
# ot - Captura solapada 356/600
# ot - Captura solapada 357/600
# ot - Captura solapada 358/600
# ot - Captura solapada 359/600
# ot - Captura solapada 360/600
# ot - Captura solapada 361/600
# ot - Captura solapada 362/600
# ot - Captura solapada 363/600
# ot - Captura solapada 364/600
# ot - Captura solapada 365/600
# ot - Captura solapada 366/600
# ot - Captura solapada 367/600
# ot - Captura solapada 368/600
# ot - Captura solapada 369/600
# ot - Captura solapada 370/600
# ot - Captura solapada 371/600
# ot - Captura solapada 372/600
# ot - Captura solapada 373/600
# ot - Captura solapada 374/600
# ot - Captura solapada 375/600
# ot - Captura solapada 376/600
# ot - Captura solapada 377/600
# ot - Captura solapada 378/600
# ot - Captura solapada 379/600
# ot - Captura solapada 380/600
# ot - Captura solapada 381/600
# ot - Captura solapada 382/600
# ot - Captura solapada 383/600
# ot - Captura solapada 384/600
# ot - Captura solapada 385/600
# ot - Captura solapada 386/600
# ot - Captura solapada 387/600
# ot - Captura solapada 388/600
# ot - Captura solapada 389/600
# ot - Captura solapada 390/600
# ot - Captura solapada 391/600
# ot - Captura solapada 392/600
# ot - Captura solapada 393/600
# ot - Captura solapada 394/600
# ot - Captura solapada 395/600
# ot - Captura solapada 396/600
# ot - Captura solapada 397/600
# ot - Captura solapada 398/600
# ot - Captura solapada 399/600
# ot - Captura solapada 400/600
# ot - Captura solapada 401/600
# ot - Captura solapada 402/600
# ot - Captura solapada 403/600
# ot - Captura solapada 404/600
# ot - Captura solapada 405/600
# ot - Captura solapada 406/600
# ot - Captura solapada 407/600
# ot - Captura solapada 408/600
# ot - Captura solapada 409/600
# ot - Captura solapada 410/600
# ot - Captura solapada 411/600
# ot - Captura solapada 412/600
# ot - Captura solapada 413/600
# ot - Captura solapada 414/600
# ot - Captura solapada 415/600
# ot - Captura solapada 416/600
# ot - Captura solapada 417/600
# ot - Captura solapada 418/600
# ot - Captura solapada 419/600
# ot - Captura solapada 420/600
# ot - Captura solapada 421/600
# ot - Captura solapada 422/600
# ot - Captura solapada 423/600
# ot - Captura solapada 424/600
# ot - Captura solapada 425/600
# ot - Captura solapada 426/600
# ot - Captura solapada 427/600
# ot - Captura solapada 428/600
# ot - Captura solapada 429/600
# ot - Captura solapada 430/600
# ot - Captura solapada 431/600
# ot - Captura solapada 432/600
# ot - Captura solapada 433/600
# ot - Captura solapada 434/600
# ot - Captura solapada 435/600
# ot - Captura solapada 436/600
# ot - Captura solapada 437/600
# ot - Captura solapada 438/600
# ot - Captura solapada 439/600
# ot - Captura solapada 440/600
# ot - Captura solapada 441/600
# ot - Captura solapada 442/600
# ot - Captura solapada 443/600
# ot - Captura solapada 444/600
# ot - Captura solapada 445/600
# ot - Captura solapada 446/600
# ot - Captura solapada 447/600
# ot - Captura solapada 448/600
# ot - Captura solapada 449/600
# ot - Captura solapada 450/600
# ot - Captura solapada 451/600
# ot - Captura solapada 452/600
# ot - Captura solapada 453/600
# ot - Captura solapada 454/600
# ot - Captura solapada 455/600
# ot - Captura solapada 456/600
# ot - Captura solapada 457/600
# ot - Captura solapada 458/600
# ot - Captura solapada 459/600
# ot - Captura solapada 460/600
# ot - Captura solapada 461/600
# ot - Captura solapada 462/600
# ot - Captura solapada 463/600
# ot - Captura solapada 464/600
# ot - Captura solapada 465/600
# ot - Captura solapada 466/600
# ot - Captura solapada 467/600
# ot - Captura solapada 468/600
# ot - Captura solapada 469/600
# ot - Captura solapada 470/600
# ot - Captura solapada 471/600
# ot - Captura solapada 472/600
# ot - Captura solapada 473/600
# ot - Captura solapada 474/600
# ot - Captura solapada 475/600
# ot - Captura solapada 476/600
# ot - Captura solapada 477/600
# ot - Captura solapada 478/600
# ot - Captura solapada 479/600
# ot - Captura solapada 480/600
# ot - Captura solapada 481/600
# ot - Captura solapada 482/600
# ot - Captura solapada 483/600
# ot - Captura solapada 484/600
# ot - Captura solapada 485/600
# ot - Captura solapada 486/600
# ot - Captura solapada 487/600
# ot - Captura solapada 488/600
# ot - Captura solapada 489/600
# ot - Captura solapada 490/600
# ot - Captura solapada 491/600
# ot - Captura solapada 492/600
# ot - Captura solapada 493/600
# ot - Captura solapada 494/600
# ot - Captura solapada 495/600
# ot - Captura solapada 496/600
# ot - Captura solapada 497/600
# ot - Captura solapada 498/600
# ot - Captura solapada 499/600
# ot - Captura solapada 500/600
# ot - Captura solapada 501/600
# ot - Captura solapada 502/600
# ot - Captura solapada 503/600
# ot - Captura solapada 504/600
# ot - Captura solapada 505/600
# ot - Captura solapada 506/600
# ot - Captura solapada 507/600
# ot - Captura solapada 508/600
# ot - Captura solapada 509/600
# ot - Captura solapada 510/600
# ot - Captura solapada 511/600
# ot - Captura solapada 512/600
# ot - Captura solapada 513/600
# ot - Captura solapada 514/600
# ot - Captura solapada 515/600
# ot - Captura solapada 516/600
# ot - Captura solapada 517/600
# ot - Captura solapada 518/600
# ot - Captura solapada 519/600
# ot - Captura solapada 520/600
# ot - Captura solapada 521/600
# ot - Captura solapada 522/600
# ot - Captura solapada 523/600
# ot - Captura solapada 524/600
# ot - Captura solapada 525/600
# ot - Captura solapada 526/600
# ot - Captura solapada 527/600
# ot - Captura solapada 528/600
# ot - Captura solapada 529/600
# ot - Captura solapada 530/600
# ot - Captura solapada 531/600
# ot - Captura solapada 532/600
# ot - Captura solapada 533/600
# ot - Captura solapada 534/600
# ot - Captura solapada 535/600
# ot - Captura solapada 536/600
# ot - Captura solapada 537/600
# ot - Captura solapada 538/600
# ot - Captura solapada 539/600
# ot - Captura solapada 540/600
# ot - Captura solapada 541/600
# ot - Captura solapada 542/600
# ot - Captura solapada 543/600
# ot - Captura solapada 544/600
# ot - Captura solapada 545/600
# ot - Captura solapada 546/600
# ot - Captura solapada 547/600
# ot - Captura solapada 548/600
# ot - Captura solapada 549/600
# ot - Captura solapada 550/600
# ot - Captura solapada 551/600
# ot - Captura solapada 552/600
# ot - Captura solapada 553/600
# ot - Captura solapada 554/600
# ot - Captura solapada 555/600
# ot - Captura solapada 556/600
# ot - Captura solapada 557/600
# ot - Captura solapada 558/600
# ot - Captura solapada 559/600
# ot - Captura solapada 560/600
# ot - Captura solapada 561/600
# ot - Captura solapada 562/600
# ot - Captura solapada 563/600
# ot - Captura solapada 564/600
# ot - Captura solapada 565/600
# ot - Captura solapada 566/600
# ot - Captura solapada 567/600
# ot - Captura solapada 568/600
# ot - Captura solapada 569/600
# ot - Captura solapada 570/600
# ot - Captura solapada 571/600
# ot - Captura solapada 572/600
# ot - Captura solapada 573/600
# ot - Captura solapada 574/600
# ot - Captura solapada 575/600
# ot - Captura solapada 576/600
# ot - Captura solapada 577/600
# ot - Captura solapada 578/600
# ot - Captura solapada 579/600
# ot - Captura solapada 580/600
# ot - Captura solapada 581/600
# ot - Captura solapada 582/600
# ot - Captura solapada 583/600
# ot - Captura solapada 584/600
# ot - Captura solapada 585/600
# ot - Captura solapada 586/600
# ot - Captura solapada 587/600
# ot - Captura solapada 588/600
# ot - Captura solapada 589/600
# ot - Captura solapada 590/600
# ot - Captura solapada 591/600
# ot - Captura solapada 592/600
# ot - Captura solapada 593/600
# ot - Captura solapada 594/600
# ot - Captura solapada 595/600
# ot - Captura solapada 596/600
# ot - Captura solapada 597/600
# ot - Captura solapada 598/600
# ot - Captura solapada 599/600
# ot - Captura solapada 600/600
# 'ot' completado con imágenes solapadas.
#
# 🎉 Captura finalizada para 'ot' con 600 imágenes.
